# %%
# 패키지
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
# 크롬드라이버 다운 - 버전 주의
# 프로그램에서 실행
file_path = "c:/ChromeDriver_exe/chrome_109_driver.exe"
driver = webdriver.Chrome(file_path)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_15708\597312094.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(file_path)

# %%
# url 주소 전달
url = "http://www.naver.com"
driver.get(url)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\anaconda3\envs\pknu_base\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\anaconda3\envs\pknu_base\lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~\anaconda3\envs\pknu_base\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ConnectionRefusedError: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~\anaconda3\envs\pknu_base\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~\anaconda3\envs\pknu_base\lib\site-packages\urllib3\connectionpool.py:398, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     397     else:
# --> 398         conn.request(method, url, **httplib_request_kw)
#     400 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     401 # legitimately able to close the connection after sending a valid response.
#     402 # With this behaviour, the received response is still readable.
#
# File ~\anaconda3\envs\pknu_base\lib\site-packages\urllib3\connection.py:239, in HTTPConnection.request(self, method, url, body, headers)
#     238     headers["User-Agent"] = _get_default_user_agent()
# --> 239 super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#
# File ~\anaconda3\envs\pknu_base\lib\http\client.py:1285, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1284 """Send a complete request to the server."""
# -> 1285 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\anaconda3\envs\pknu_base\lib\http\client.py:1331, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1330     body = _encode(body, 'body')
# -> 1331 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~\anaconda3\envs\pknu_base\lib\http\client.py:1280, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1279     raise CannotSendHeader()
# -> 1280 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~\anaconda3\envs\pknu_base\lib\http\client.py:1040, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1039 del self._buffer[:]
# -> 1040 self.send(msg)
#    1042 if message_body is not None:
#    1043
#    1044     # create a consistent interface to message_body
#
# File ~\anaconda3\envs\pknu_base\lib\http\client.py:980, in HTTPConnection.send(self, data)
#     979 if self.auto_open:
# --> 980     self.connect()
#     981 else:
#
# File ~\anaconda3\envs\pknu_base\lib\site-packages\urllib3\connection.py:205, in HTTPConnection.connect(self)
#     204 def connect(self):
# --> 205     conn = self._new_conn()
#     206     self._prepare_conn(conn)
#
# File ~\anaconda3\envs\pknu_base\lib\site-packages\urllib3\connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x00000224642E86A0>: Failed to establish a new connection: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# Cell In[46], line 3
#       1 # url 주소 전달
#       2 url = "http://www.naver.com"
# ----> 3 driver.get(url)
#
# File ~\anaconda3\envs\pknu_base\lib\site-packages\selenium\webdriver\remote\webdriver.py:449, in WebDriver.get(self, url)
#     447 def get(self, url: str) -> None:
#     448     """Loads a web page in the current browser session."""
# --> 449     self.execute(Command.GET, {"url": url})
#
# File ~\anaconda3\envs\pknu_base\lib\site-packages\selenium\webdriver\remote\webdriver.py:438, in WebDriver.execute(self, driver_command, params)
#     435     elif "sessionId" not in params:
#     436         params["sessionId"] = self.session_id
# --> 438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
#     440     self.error_handler.check_response(response)
#
# File ~\anaconda3\envs\pknu_base\lib\site-packages\selenium\webdriver\remote\remote_connection.py:290, in RemoteConnection.execute(self, command, params)
#     288 data = utils.dump_json(params)
#     289 url = f"{self._url}{path}"
# --> 290 return self._request(command_info[0], url, body=data)
#
# File ~\anaconda3\envs\pknu_base\lib\site-packages\selenium\webdriver\remote\remote_connection.py:311, in RemoteConnection._request(self, method, url, body)
#     308     body = None
#     310 if self.keep_alive:
# --> 311     response = self._conn.request(method, url, body=body, headers=headers)
#     312     statuscode = response.status
#     313 else:
#
# File ~\anaconda3\envs\pknu_base\lib\site-packages\urllib3\request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File ~\anaconda3\envs\pknu_base\lib\site-packages\urllib3\request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File ~\anaconda3\envs\pknu_base\lib\site-packages\urllib3\poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File ~\anaconda3\envs\pknu_base\lib\site-packages\urllib3\connectionpool.py:815, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     810 if not conn:
#     811     # Try again
#     812     log.warning(
#     813         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     814     )
# --> 815     return self.urlopen(
#     816         method,
#     817         url,
#     818         body,
#     819         headers,
#     820         retries,
#     821         redirect,
#     822         assert_same_host,
#     823         timeout=timeout,
#     824         pool_timeout=pool_timeout,
#     825         release_conn=release_conn,
#     826         chunked=chunked,
#     827         body_pos=body_pos,
#     828         **response_kw
#     829     )
#     831 # Handle redirect?
#     832 redirect_location = redirect and response.get_redirect_location()
#
# File ~\anaconda3\envs\pknu_base\lib\site-packages\urllib3\connectionpool.py:815, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     810 if not conn:
#     811     # Try again
#     812     log.warning(
#     813         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     814     )
# --> 815     return self.urlopen(
#     816         method,
#     817         url,
#     818         body,
#     819         headers,
#     820         retries,
#     821         redirect,
#     822         assert_same_host,
#     823         timeout=timeout,
#     824         pool_timeout=pool_timeout,
#     825         release_conn=release_conn,
#     826         chunked=chunked,
#     827         body_pos=body_pos,
#     828         **response_kw
#     829     )
#     831 # Handle redirect?
#     832 redirect_location = redirect and response.get_redirect_location()
#
# File ~\anaconda3\envs\pknu_base\lib\site-packages\urllib3\connectionpool.py:815, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     810 if not conn:
#     811     # Try again
#     812     log.warning(
#     813         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     814     )
# --> 815     return self.urlopen(
#     816         method,
#     817         url,
#     818         body,
#     819         headers,
#     820         retries,
#     821         redirect,
#     822         assert_same_host,
#     823         timeout=timeout,
#     824         pool_timeout=pool_timeout,
#     825         release_conn=release_conn,
#     826         chunked=chunked,
#     827         body_pos=body_pos,
#     828         **response_kw
#     829     )
#     831 # Handle redirect?
#     832 redirect_location = redirect and response.get_redirect_location()
#
# File ~\anaconda3\envs\pknu_base\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     784 elif isinstance(e, (SocketError, HTTPException)):
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#     792 # Keep track of the error for the retry warning.
#
# File ~\anaconda3\envs\pknu_base\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     581 new_retry = self.new(
#     582     total=total,
#     583     connect=connect,
#    (...)
#     588     history=history,
#     589 )
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#     596 return new_retry
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=59874): Max retries exceeded with url: /session/f695ebbc876554d0b61f19ed1675a3a4/url (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000224642E86A0>: Failed to establish a new connection: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다'))

# %%
# 페이지 정보(html) 확인하기
html = driver.page_source
html
# Out:
# '<html lang="ko" data-dark="false" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36"><head><script async="" type="text/javascript" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-core.js"></script> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"> <meta name="robots" content="index,nofollow"> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요">  <link rel="stylesheet" href="https://pm.pstatic.net/dist/css/nmain.20221110.css"> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css"> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1">  <link rel="apple-touch-icon" sizes="114x114" href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png"> <link rel="apple-touch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png"> <script>window.nmain=window.nmain||{},window.nmain.supportFlicking=!1;var nsc="navertop.v4",ua=navigator.userAgent,useIeJSFlag="1";window.nmain.isIE="0"===useIeJSFlag,document.getElementsByTagName("html")[0].setAttribute("data-useragent",ua),window.nmain.isIE&&(Object.create=function(n){function e(){}return e.prototype=n,new e})</script> <script>var darkmode= false;window.naver_corp_da=window.naver_corp_da||{main:{}},window.naver_corp_da.main=window.naver_corp_da.main||{},window.naver_corp_da.main.darkmode=darkmode,window.gladsdk=window.gladsdk||{cmd:[]},window.gladsdk.cmd.push((function(){window.gladsdk.setHostMeta("theme",darkmode?"dark":"light")})),window.ndpsdk=window.ndpsdk||{cmd:[],polyfill:{cmd:[]}},window.ndpsdk.cmd.push((function(){window.ndpsdk.setHostMeta("theme",darkmode?"dark":"light")}))</script>  <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script async="" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script>  <script> window.nmain.gv = {  isLogin: false,\nuseId: null,   daInfo: {"BEAUTY":{"menu":"BEAUTY","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000163","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_1","tb":"BEAUTY_1","unit":"SU10595","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000164","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_2","tb":"BEAUTY_1","unit":"SU10596","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVING":{"menu":"LIVING","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000183","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_1","tb":"LIVING_1","unit":"SU10597","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000184","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_2","tb":"LIVING_1","unit":"SU10606","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVINGHOME":{"menu":"LIVINGHOME","childMenu":"" ...

# %%
# html 형태로 변환
soup = BeautifulSoup(html,"html.parser")
soup
# Out:
# <html data-dark="false" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36" lang="ko"><head><script async="" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-core.js" type="text/javascript"></script> <meta charset="utf-8"/> <title>NAVER</title> <meta content="IE=edge" http-equiv="X-UA-Compatible"/> <meta content="width=1190" name="viewport"/> <meta content="NAVER" name="apple-mobile-web-app-title"/> <meta content="index,nofollow" name="robots"/> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description"/> <meta content="네이버" property="og:title"/> <meta content="https://www.naver.com/" property="og:url"/> <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description"/> <meta content="summary" name="twitter:card"/> <meta content="" name="twitter:title"/> <meta content="https://www.naver.com/" name="twitter:url"/> <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" name="twitter:image"/> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="twitter:description"/> <link href="https://pm.pstatic.net/dist/css/nmain.20221110.css" rel="stylesheet"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css" rel="stylesheet"/> <link href="/favicon.ico?1" rel="shortcut icon" type="image/x-icon"/> <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png" rel="apple-touch-icon" sizes="114x114"/> <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png" rel="apple-touch-icon"/> <script>window.nmain=window.nmain||{},window.nmain.supportFlicking=!1;var nsc="navertop.v4",ua=navigator.userAgent,useIeJSFlag="1";window.nmain.isIE="0"===useIeJSFlag,document.getElementsByTagName("html")[0].setAttribute("data-useragent",ua),window.nmain.isIE&&(Object.create=function(n){function e(){}return e.prototype=n,new e})</script> <script>var darkmode= false;window.naver_corp_da=window.naver_corp_da||{main:{}},window.naver_corp_da.main=window.naver_corp_da.main||{},window.naver_corp_da.main.darkmode=darkmode,window.gladsdk=window.gladsdk||{cmd:[]},window.gladsdk.cmd.push((function(){window.gladsdk.setHostMeta("theme",darkmode?"dark":"light")})),window.ndpsdk=window.ndpsdk||{cmd:[],polyfill:{cmd:[]}},window.ndpsdk.cmd.push((function(){window.ndpsdk.setHostMeta("theme",darkmode?"dark":"light")}))</script> <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script async="" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script> <script> window.nmain.gv = {  isLogin: false,
# useId: null,   daInfo: {"BEAUTY":{"menu":"BEAUTY","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000163","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_1","tb":"BEAUTY_1","unit":"SU10595","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000164","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_2","tb":"BEAUTY_1","unit":"SU10596","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVING":{"menu":"LIVING","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000183","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_1","tb":"LIVING_1","unit":"SU10597","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000184","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_2","tb":"LIVING_1","unit":"SU10606","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVINGHOME":{"menu":"LIVINGHOME","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000185","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_livinghome_1","tb":"LIVINGHOME_1","unit":"SU10571","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000186","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_livinghome_2","tb":"LIVINGHOME_1","unit":"SU10572","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]}},
# svt: 20230201142524,
# }; </script> <script> window.nmain.newsstand = {
# rcode: '02135103',
# newsCastSubsInfo: '',
# newsStandSubsInfo: ''
# };
# window.etc = {  };
# window.svr = "<!--cvweb03-->"; </script> <script defer="defer" src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js"></script> <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/external.2961eaa5.js?o=www" type="text/javascript"></script> <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/preload.5fe99fda.js?o=www" type="text/javascript"></script> <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/polyfill.f3c68d2d.js?o=www" type="text/javascript"></script> <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/vendors~more~nmain~notice~search~sidebar_notice.40da85e0.js?o=www" type="text/javascript"></script> <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/search.607b49e4.js?o=www" type="text/javascript"></script> <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/vendors~more~nmain~sidebar_notice.7aad5e27.js?o=www" type="text/javascript"></script> <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/nmain.e31af4db.js?o=www" type="text/javascript"></script> <style>:root{color-scheme:light}#_nx_kbd .setkorhelp a{display:none}</style> <script async="" charset="utf-8" src="https://ssl.pstatic.net/tveta/libs/glad/prod/2.9.1/gfp-sdk.js" type="text/javascript"></script><script async="" charset="utf-8" src="https://ssl.pstatic.net/tveta/libs/glad/prod/2.9.1/gfp-sentry-bundle-1.0.1.js" type="text/javascript"></script><style>.ly_inputko {
# 	position: absolute;
# 	top: 38px;
# 	left: 404px;
# 	z-index: 900;
# 	width: 313px;
# 	padding: 0 10px;
# 	border: 1px solid #b8b8b8;
# 	line-height: 14px;
# 	background-color: #f6f6f6;
# }
#
# .ly_inputko.ly_inputko_over {
# 	border: 1px solid #72747f;
# 	cursor: move;
# }
#
# .ly_inputko button {
# 	border: 0;
# 	background: none;
# 	cursor: pointer;
# }
#
# .ly_inputko .tab_inkey {
# 	display: inline-block;
# 	position: absolute;
# 	top: 15px;
# 	left: 10px;
# 	width: 78px;
# 	height: 11px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/btn_sp_v3.png) no-repeat -80px -660px;
# }
#
# .ly_inputko .tab_inkey button {
# 	display: block;
# 	width: 78px;
# 	height: 11px;
# }
#
# .ly_inputko .inkeyon {
# 	background-position: -80px -640px;
# }
#
# .ly_inputko .tab_inms {
# 	display: inline-block;
# 	position: absolute;
# 	top: 15px;
# 	left: 108px;
# 	width: 78px;
# 	height: 11px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/btn_sp_v3.png) no-repeat -174px -660px;
# }
#
# .ly_inputko .tab_inms button {
# 	display: block;
# 	width: 78px;
# 	height: 11px;
# }
#
# .ly_inputko .inmson {
# 	background-position: -174px -640px;
# }
#
# .ly_inputko .bar {
# 	position: absolute;
# 	top: 16px;
# 	left: 93px;
# }
#
# .ly_inputko .inputko_info {
# 	clear: both;
# 	position: relative;
# 	z-index: 2;
# 	width: 100%;
# 	padding: 9px 0 0;
# 	background: #f6f6f6 url(https://ssl.pstatic.net/sstatic/search/img3/bg_sp_x.gif) repeat-x;
# }
#
# .ly_inputko .inputko_info li {
# 	padding: 2px 0 0 8px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/bu_sp.gif) no-repeat 0 -393px;
# 	font-size: 11px;
# 	color: #333;
# 	letter-spacing: -1px;
# 	text-align: left;
# }
#
# .ly_inputko .inputko_info li span {
# 	display: inline-block;
# 	width: 9px;
# 	height: 9px;
# 	*height: 11px;
# 	margin: 0 1px 0 2px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/bu_sp.gif) no-repeat 0 -60px;
# }
#
# .ly_inputko .inputko_info li em {
# 	color: #666;
# }
#
# .ly_inputko .btn_ly_cl {
# 	position: absolute;
# 	top: 12px;
# 	right: 12px;
# 	width: 12px;
# 	height: 12px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/btn_sp_v3.png) no-repeat -60px -80px;
# }
#
# .ly_inputko .btn_ly_cl button {
# 	width: 12px;
# 	height: 12px;
# }
#
# .ly_inputko .setkorhelp {
# 	margin: 4px 0 12px 5px;
# 	text-align: left;
# }
#
# .ly_inputko .setkorhelp a {
# 	font-size: 11px;
# 	color: #666;
# 	letter-spacing: -1px;
# 	text-decoration: underline;
# }
#
# /* keyboard */
# .ly_inputko .inputko_keyboard {
# 	width: 313px;
# 	margin-top: 39px;
# 	background-color: #f6f6f6;
# }
#
# .ly_inputko .keyboard {
# 	position: relative;
# 	z-index: 2;
# 	height: 105px;
# 	padding-bottom: 14px;
# 	background-color: #f6f6f6;
# }
#
# .ly_inputko .keyboard_info {
# 	overflow: auto;
# 	width: 313px;
# 	height: 105px;
# }
#
# .ly_inputko .keyboard_info h3 {
# 	font-size: 12px;
# }
#
# .ly_inputko .keyboard_info h4 {
# 	clear: both;
# 	font-size: 11px;
# }
#
# .ly_inputko .keyboard_info li {
# 	float: left;
# 	margin-right: 5px;
# 	font-size: 11px;
# }
#
# .ly_inputko .keyboard_img {
# 	position: absolute;
# 	top: 0;
# 	left: 0;
# 	width: 313px;
# 	height: 105px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/bg_sp.gif) no-repeat;
# }
#
# .ly_inputko .inputko_keyboard .setkorhelp {
# 	position: relative;
# 	z-index: 2;
# 	margin: 0 0 0 8px;
# 	padding: 4px 0 12px;
# 	background-color: #f6f6f6;
# }
#
# /* mouse */
# .ly_inputko .inputko_mouse {
# 	width: 313px;
# 	margin-top: 57px;
# }
#
# .ly_inputko .inputko_mouse .btn_inko {
# 	position: absolute;
# 	z-index: 1;
# 	width: 25px;
# 	height: 25px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/btn_sp_v3.png) no-repeat 0 -280px;
# }
#
# .ly_inputko .inputko_mouse .btn_inko button {
# 	width: 25px;
# 	height: 25px;
# }
#
# .ly_inputko .inputko_mouse .inputko_info {
# 	z-index: 1;
# 	margin-top: 10px;
# }
#
# .ly_inputko .inputko_mouse .bar2 {
# 	position: absolute;
# 	top: 39px;
# 	left: 34px;
# 	color: #ddd;
# }
#
# .ly_inputko .inputko_mouse .inputko_info li {
# 	padding: 2px 0 0 4px;
# 	background: none;
# }
#
# .ly_inputko .mouse_kor, .mouse_eng {
# 	display: none;
# }
#
# .ly_inputko .btn_kor {
# 	position: absolute;
# 	top: 40px;
# 	left: 11px;
# 	z-index: 1;
# 	width: 22px;
# 	height: 10px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/btn_sp_v3.png) no-repeat -380px -40px;
# }
#
# .ly_inputko .btn_kor_on {
# 	position: absolute;
# 	top: 40px;
# 	left: 11px;
# 	z-index: 1;
# 	width: 22px;
# 	height: 10px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/btn_sp_v3.png) no-repeat -420px -40px;
# }
#
# .ly_inputko .btn_eng {
# 	position: absolute;
# 	top: 40px;
# 	left: 43px;
# 	width: 22px;
# 	height: 10px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/btn_sp_v3.png) no-repeat -380px -60px;
# }
#
# .ly_inputko .btn_eng_on {
# 	position: absolute;
# 	top: 40px;
# 	left: 43px;
# 	width: 22px;
# 	height: 10px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/btn_sp_v3.png) no-repeat -420px -60px;
# }
#
# .ly_inputko .btn_kor button, .ly_inputko .btn_kor_on button, .ly_inputko .btn_eng button, .ly_inputko .btn_eng_on button {
# 	display: block;
# 	width: 22px;
# 	height: 11px;
# }
#
# .ly_inputko .btn_mouse {
# 	overflow: hidden;
# 	clear: both;
# 	width: 131px;
# 	height: 20px;
# 	_height: 27px;
# 	margin: 0 auto;
# 	padding-top: 7px;
# }
#
# .ly_inputko .btn_space {
# 	display: inline-block;
# 	width: 47px;
# 	height: 20px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/btn_sp_v3.png) no-repeat -160px -40px;
# }
#
# .ly_inputko .btn_space button {
# 	width: 47px;
# 	height: 20px;
# }
#
# .ly_inputko .btn_space_over {
# 	background-position: -160px -60px;
# }
#
# .ly_inputko .btn_del {
# 	display: inline-block;
# 	width: 39px;
# 	height: 20px;
# 	margin-left: 3px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/btn_sp_v3.png) no-repeat -220px -40px;
# }
#
# .ly_inputko .btn_del button {
# 	width: 39px;
# 	height: 20px;
# }
#
# .ly_inputko .btn_del_over {
# 	background-position: -220px -60px;
# }
#
# .ly_inputko .btn_reset {
# 	display: inline-block;
# 	width: 39px;
# 	height: 20px;
# 	margin-left: 3px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/btn_sp_v3.png) no-repeat -260px -40px;
# }
#
# .ly_inputko .btn_reset button {
# 	width: 39px;
# 	height: 20px;
# }
#
# .ly_inputko .btn_reset_over {
# 	background-position: -260px -60px;
# }
#
# .ly_inputko .number {
# 	overflow: hidden;
# 	float: left;
# 	_float: none;
# 	position: relative;
# 	width: 313px;
# 	height: 28px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/bg_sp.gif) no-repeat 0 -202px;
# }
#
# .ly_inputko .number .num {
# 	top: 1px;
# 	left: 1px;
# 	background-position: 0 -400px;
# }
#
# .ly_inputko .number .num2 {
# 	top: 1px;
# 	left: 27px;
# 	background-position: -40px -400px;
# }
#
# .ly_inputko .number .num3 {
# 	top: 1px;
# 	left: 53px;
# 	background-position: -80px -400px;
# }
#
# .ly_inputko .number .num4 {
# 	top: 1px;
# 	left: 79px;
# 	background-position: -120px -400px;
# }
#
# .ly_inputko .number .num5 {
# 	top: 1px;
# 	left: 105px;
# 	background-position: -160px -400px;
# }
#
# .ly_inputko .number .num6 {
# 	top: 1px;
# 	left: 131px;
# 	background-position: -200px -400px;
# }
#
# .ly_inputko .number .num7 {
# 	top: 1px;
# 	left: 157px;
# 	background-position: -240px -400px;
# }
#
# .ly_inputko .number .num8 {
# 	top: 1px;
# 	left: 183px;
# 	background-position: -280px -400px;
# }
#
# .ly_inputko .number .num9 {
# 	top: 1px;
# 	left: 209px;
# 	background-position: -320px -400px;
# }
#
# .ly_inputko .number .num0 {
# 	top: 1px;
# 	left: 235px;
# 	background-position: -360px -400px;
# }
#
# .ly_inputko .number .period {
# 	top: 1px;
# 	left: 261px;
# 	background-position: -400px -400px;
# }
#
# .ly_inputko .number .num_over {
# 	top: 0;
# 	left: 0;
# 	width: 27px;
# 	height: 27px;
# 	background-position: 0 -240px;
# }
#
# .ly_inputko .number .num2_over {
# 	top: 0;
# 	left: 26px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -40px -240px;
# }
#
# .ly_inputko .number .num3_over {
# 	top: 0;
# 	left: 52px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -80px -240px;
# }
#
# .ly_inputko .number .num4_over {
# 	top: 0;
# 	left: 78px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -120px -240px;
# }
#
# .ly_inputko .number .num5_over {
# 	top: 0;
# 	left: 104px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -160px -240px;
# }
#
# .ly_inputko .number .num6_over {
# 	top: 0;
# 	left: 130px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -200px -240px;
# }
#
# .ly_inputko .number .num7_over {
# 	top: 0;
# 	left: 156px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -240px -240px;
# }
#
# .ly_inputko .number .num8_over {
# 	top: 0;
# 	left: 182px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -280px -240px;
# }
#
# .ly_inputko .number .num9_over {
# 	top: 0;
# 	left: 208px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -320px -240px;
# }
#
# .ly_inputko .number .num0_over {
# 	top: 0;
# 	left: 234px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -360px -240px;
# }
#
# .ly_inputko .number .period_over {
# 	top: 0;
# 	left: 260px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -400px -240px;
# }
#
# /* mouse korean */
# .ly_inputko .consonantal {
# 	float: left;
# 	position: relative;
# 	width: 181px;
# 	height: 79px;
# 	margin-bottom: 3px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/bg_sp.gif) no-repeat 0 -120px;
# }
#
# .ly_inputko .vowel {
# 	position: absolute;
# 	top: 57px;
# 	left: 194px;
# 	width: 129px;
# 	height: 79px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/bg_sp.gif) no-repeat -184px -120px;
# }
#
# .ly_inputko .consonantal .con {
# 	top: 1px;
# 	left: 1px;
# 	width: 24px;
# 	background-position: 0 -280px;
# }
#
# .ly_inputko .consonantal .con2 {
# 	top: 1px;
# 	left: 26px;
# 	background-position: -40px -280px;
# }
#
# .ly_inputko .consonantal .con3 {
# 	top: 1px;
# 	left: 52px;
# 	background-position: -80px -280px;
# }
#
# .ly_inputko .consonantal .con4 {
# 	top: 1px;
# 	left: 78px;
# 	background-position: -120px -280px;
# }
#
# .ly_inputko .consonantal .con5 {
# 	top: 1px;
# 	left: 104px;
# 	background-position: -160px -280px;
# }
#
# .ly_inputko .consonantal .con6 {
# 	top: 1px;
# 	left: 130px;
# 	background-position: -200px -280px;
# }
#
# .ly_inputko .consonantal .con7 {
# 	top: 1px;
# 	left: 156px;
# 	background-position: -240px -280px;
# }
#
# .ly_inputko .consonantal .con8 {
# 	top: 27px;
# 	left: 1px;
# 	width: 24px;
# 	background-position: 0 -320px;
# }
#
# .ly_inputko .consonantal .con9 {
# 	top: 27px;
# 	left: 26px;
# 	background-position: -40px -320px;
# }
#
# .ly_inputko .consonantal .con10 {
# 	top: 27px;
# 	left: 52px;
# 	background-position: -80px -320px;
# }
#
# .ly_inputko .consonantal .con11 {
# 	top: 27px;
# 	left: 78px;
# 	background-position: -120px -320px;
# }
#
# .ly_inputko .consonantal .con12 {
# 	top: 27px;
# 	left: 104px;
# 	background-position: -160px -320px;
# }
#
# .ly_inputko .consonantal .con13 {
# 	top: 27px;
# 	left: 130px;
# 	background-position: -200px -320px;
# }
#
# .ly_inputko .consonantal .con14 {
# 	top: 27px;
# 	left: 156px;
# 	background-position: -240px -320px;
# }
#
# .ly_inputko .consonantal .con15 {
# 	top: 53px;
# 	left: 1px;
# 	width: 24px;
# 	background-position: 0 -360px;
# }
#
# .ly_inputko .consonantal .con16 {
# 	top: 53px;
# 	left: 26px;
# 	background-position: -40px -360px;
# }
#
# .ly_inputko .consonantal .con17 {
# 	top: 53px;
# 	left: 52px;
# 	background-position: -80px -360px;
# }
#
# .ly_inputko .consonantal .con18 {
# 	top: 53px;
# 	left: 78px;
# 	background-position: -120px -360px;
# }
#
# .ly_inputko .consonantal .con19 {
# 	top: 53px;
# 	left: 104px;
# 	background-position: -160px -360px;
# }
#
# .ly_inputko .consonantal .con_over {
# 	top: 0;
# 	left: 0;
# 	width: 26px;
# 	height: 27px;
# 	background-position: 0 -120px;
# }
#
# .ly_inputko .consonantal .con2_over {
# 	top: 0;
# 	left: 25px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -40px -120px;
# }
#
# .ly_inputko .consonantal .con3_over {
# 	top: 0;
# 	left: 51px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -80px -120px;
# }
#
# .ly_inputko .consonantal .con4_over {
# 	top: 0;
# 	left: 77px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -120px -120px;
# }
#
# .ly_inputko .consonantal .con5_over {
# 	top: 0;
# 	left: 103px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -160px -120px;
# }
#
# .ly_inputko .consonantal .con6_over {
# 	top: 0;
# 	left: 129px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -200px -120px;
# }
#
# .ly_inputko .consonantal .con7_over {
# 	top: 0;
# 	left: 155px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -240px -120px;
# }
#
# .ly_inputko .consonantal .con8_over {
# 	top: 26px;
# 	left: 0;
# 	width: 26px;
# 	height: 27px;
# 	background-position: 0 -160px;
# }
#
# .ly_inputko .consonantal .con9_over {
# 	top: 26px;
# 	left: 25px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -40px -160px;
# }
#
# .ly_inputko .consonantal .con10_over {
# 	top: 26px;
# 	left: 51px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -80px -160px;
# }
#
# .ly_inputko .consonantal .con11_over {
# 	top: 26px;
# 	left: 77px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -120px -160px;
# }
#
# .ly_inputko .consonantal .con12_over {
# 	top: 26px;
# 	left: 103px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -160px -160px;
# }
#
# .ly_inputko .consonantal .con13_over {
# 	top: 26px;
# 	left: 129px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -200px -160px;
# }
#
# .ly_inputko .consonantal .con14_over {
# 	top: 26px;
# 	left: 155px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -240px -160px;
# }
#
# .ly_inputko .consonantal .con15_over {
# 	top: 52px;
# 	left: 0;
# 	width: 26px;
# 	height: 27px;
# 	background-position: 0 -200px;
# }
#
# .ly_inputko .consonantal .con16_over {
# 	top: 52px;
# 	left: 25px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -40px -200px;
# }
#
# .ly_inputko .consonantal .con17_over {
# 	top: 52px;
# 	left: 51px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -80px -200px;
# }
#
# .ly_inputko .consonantal .con18_over {
# 	top: 52px;
# 	left: 77px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -120px -200px;
# }
#
# .ly_inputko .consonantal .con19_over {
# 	top: 52px;
# 	left: 103px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -160px -200px;
# }
#
# .ly_inputko .vowel .vow {
# 	top: 1px;
# 	left: 1px;
# 	width: 24px;
# 	background-position: -280px -280px;
# }
#
# .ly_inputko .vowel .vow2 {
# 	top: 1px;
# 	left: 26px;
# 	background-position: -320px -280px;
# }
#
# .ly_inputko .vowel .vow3 {
# 	top: 1px;
# 	left: 52px;
# 	background-position: -360px -280px;
# }
#
# .ly_inputko .vowel .vow4 {
# 	top: 1px;
# 	left: 78px;
# 	background-position: -400px -280px;
# }
#
# .ly_inputko .vowel .vow5 {
# 	top: 1px;
# 	left: 104px;
# 	width: 24px;
# 	background-position: -440px -280px;
# }
#
# .ly_inputko .vowel .vow6 {
# 	top: 27px;
# 	left: 1px;
# 	width: 24px;
# 	background-position: -280px -320px;
# }
#
# .ly_inputko .vowel .vow7 {
# 	top: 27px;
# 	left: 26px;
# 	background-position: -320px -320px;
# }
#
# .ly_inputko .vowel .vow8 {
# 	top: 27px;
# 	left: 52px;
# 	background-position: -360px -320px;
# }
#
# .ly_inputko .vowel .vow9 {
# 	top: 27px;
# 	left: 78px;
# 	background-position: -400px -320px;
# }
#
# .ly_inputko .vowel .vow10 {
# 	top: 27px;
# 	left: 104px;
# 	width: 24px;
# 	background-position: -440px -320px;
# }
#
# .ly_inputko .vowel .vow11 {
# 	top: 53px;
# 	left: 1px;
# 	width: 24px;
# 	background-position: -280px -360px;
# }
#
# .ly_inputko .vowel .vow12 {
# 	top: 53px;
# 	left: 26px;
# 	background-position: -320px -360px;
# }
#
# .ly_inputko .vowel .vow13 {
# 	top: 53px;
# 	left: 52px;
# 	background-position: -360px -360px;
# }
#
# .ly_inputko .vowel .vow14 {
# 	top: 53px;
# 	left: 78px;
# 	background-position: -400px -360px;
# }
#
# .ly_inputko .vowel .vow_over {
# 	top: 0;
# 	left: 0;
# 	width: 26px;
# 	height: 27px;
# 	background-position: -280px -120px;
# }
#
# .ly_inputko .vowel .vow2_over {
# 	top: 0;
# 	left: 25px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -320px -120px;
# }
#
# .ly_inputko .vowel .vow3_over {
# 	top: 0;
# 	left: 51px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -360px -120px;
# }
#
# .ly_inputko .vowel .vow4_over {
# 	top: 0;
# 	left: 77px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -400px -120px;
# }
#
# .ly_inputko .vowel .vow5_over {
# 	top: 0;
# 	left: 103px;
# 	width: 26px;
# 	height: 27px;
# 	background-position: -440px -120px;
# }
#
# .ly_inputko .vowel .vow6_over {
# 	top: 26px;
# 	left: 0;
# 	width: 26px;
# 	height: 27px;
# 	background-position: -280px -160px;
# }
#
# .ly_inputko .vowel .vow7_over {
# 	top: 26px;
# 	left: 25px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -320px -160px;
# }
#
# .ly_inputko .vowel .vow8_over {
# 	top: 26px;
# 	left: 51px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -360px -160px;
# }
#
# .ly_inputko .vowel .vow9_over {
# 	top: 26px;
# 	left: 77px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -400px -160px;
# }
#
# .ly_inputko .vowel .vow10_over {
# 	top: 26px;
# 	left: 103px;
# 	width: 26px;
# 	height: 27px;
# 	background-position: -440px -160px;
# }
#
# .ly_inputko .vowel .vow11_over {
# 	top: 52px;
# 	left: 0;
# 	width: 26px;
# 	height: 27px;
# 	background-position: -280px -200px;
# }
#
# .ly_inputko .vowel .vow12_over {
# 	top: 52px;
# 	left: 25px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -320px -200px;
# }
#
# .ly_inputko .vowel .vow13_over {
# 	top: 52px;
# 	left: 51px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -360px -200px;
# }
#
# .ly_inputko .vowel .vow14_over {
# 	top: 52px;
# 	left: 77px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -400px -200px;
# }
#
# .ly_inputko .consonantal .con button, .ly_inputko .consonantal .con8 button, .ly_inputko .consonantal .con15 button, .ly_inputko .vowel .vow button, .ly_inputko .vowel .vow5 button, .ly_inputko .vowel .vow6 button, .ly_inputko .vowel .vow10 button, .ly_inputko .vowel .vow11 button {
# 	width: 24px;
# }
#
# /* mouse english */
# .ly_inputko .alphabet {
# 	position: relative;
# 	width: 313px;
# 	height: 79px;
# 	margin-bottom: 3px;
# 	background: url(https://ssl.pstatic.net/sstatic/search/img3/bg_sp.gif) no-repeat 0 -240px;
# }
#
# .ly_inputko .alphabet .alp {
# 	top: 1px;
# 	left: 1px;
# 	background-position: 0 -560px;
# }
#
# .ly_inputko .alphabet .alp2 {
# 	top: 1px;
# 	left: 27px;
# 	background-position: -40px -560px;
# }
#
# .ly_inputko .alphabet .alp3 {
# 	top: 1px;
# 	left: 53px;
# 	background-position: -80px -560px;
# }
#
# .ly_inputko .alphabet .alp4 {
# 	top: 1px;
# 	left: 79px;
# 	background-position: -120px -560px;
# }
#
# .ly_inputko .alphabet .alp5 {
# 	top: 1px;
# 	left: 105px;
# 	background-position: -160px -560px;
# }
#
# .ly_inputko .alphabet .alp6 {
# 	top: 1px;
# 	left: 131px;
# 	background-position: -200px -560px;
# }
#
# .ly_inputko .alphabet .alp7 {
# 	top: 1px;
# 	left: 157px;
# 	background-position: -240px -560px;
# }
#
# .ly_inputko .alphabet .alp8 {
# 	top: 1px;
# 	left: 183px;
# 	background-position: -280px -560px;
# }
#
# .ly_inputko .alphabet .alp9 {
# 	top: 1px;
# 	left: 209px;
# 	background-position: -320px -560px;
# }
#
# .ly_inputko .alphabet .alp10 {
# 	top: 1px;
# 	left: 235px;
# 	background-position: -360px -560px;
# }
#
# .ly_inputko .alphabet .alp11 {
# 	top: 1px;
# 	left: 261px;
# 	background-position: -400px -560px;
# }
#
# .ly_inputko .alphabet .alp12 {
# 	top: 1px;
# 	left: 287px;
# 	background-position: -440px -560px;
# }
#
# .ly_inputko .alphabet .alp13 {
# 	top: 27px;
# 	left: 1px;
# 	background-position: 0 -600px;
# }
#
# .ly_inputko .alphabet .alp14 {
# 	top: 27px;
# 	left: 27px;
# 	background-position: -40px -600px;
# }
#
# .ly_inputko .alphabet .alp15 {
# 	top: 27px;
# 	left: 53px;
# 	background-position: -80px -600px;
# }
#
# .ly_inputko .alphabet .alp16 {
# 	top: 27px;
# 	left: 79px;
# 	background-position: -120px -600px;
# }
#
# .ly_inputko .alphabet .alp17 {
# 	top: 27px;
# 	left: 105px;
# 	background-position: -160px -600px;
# }
#
# .ly_inputko .alphabet .alp18 {
# 	top: 27px;
# 	left: 131px;
# 	background-position: -200px -600px;
# }
#
# .ly_inputko .alphabet .alp19 {
# 	top: 27px;
# 	left: 157px;
# 	background-position: -240px -600px;
# }
#
# .ly_inputko .alphabet .alp20 {
# 	top: 27px;
# 	left: 183px;
# 	background-position: -280px -600px;
# }
#
# .ly_inputko .alphabet .alp21 {
# 	top: 27px;
# 	left: 209px;
# 	background-position: -320px -600px;
# }
#
# .ly_inputko .alphabet .alp22 {
# 	top: 27px;
# 	left: 235px;
# 	background-position: -360px -600px;
# }
#
# .ly_inputko .alphabet .alp23 {
# 	top: 27px;
# 	left: 261px;
# 	background-position: -400px -600px;
# }
#
# .ly_inputko .alphabet .alp24 {
# 	top: 27px;
# 	left: 287px;
# 	background-position: -440px -600px;
# }
#
# .ly_inputko .alphabet .alp25 {
# 	top: 53px;
# 	left: 1px;
# 	background-position: 0 -640px;
# }
#
# .ly_inputko .alphabet .alp26 {
# 	top: 53px;
# 	left: 27px;
# 	background-position: -40px -640px;
# }
#
# .ly_inputko .alphabet .alp_over {
# 	top: 0;
# 	left: 0;
# 	width: 27px;
# 	height: 27px;
# 	background-position: 0 -440px;
# }
#
# .ly_inputko .alphabet .alp2_over {
# 	top: 0;
# 	left: 26px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -40px -440px;
# }
#
# .ly_inputko .alphabet .alp3_over {
# 	top: 0;
# 	left: 52px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -80px -440px;
# }
#
# .ly_inputko .alphabet .alp4_over {
# 	top: 0;
# 	left: 78px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -120px -440px;
# }
#
# .ly_inputko .alphabet .alp5_over {
# 	top: 0;
# 	left: 104px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -160px -440px;
# }
#
# .ly_inputko .alphabet .alp6_over {
# 	top: 0;
# 	left: 130px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -200px -440px;
# }
#
# .ly_inputko .alphabet .alp7_over {
# 	top: 0;
# 	left: 156px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -240px -440px;
# }
#
# .ly_inputko .alphabet .alp8_over {
# 	top: 0;
# 	left: 182px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -280px -440px;
# }
#
# .ly_inputko .alphabet .alp9_over {
# 	top: 0;
# 	left: 208px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -320px -440px;
# }
#
# .ly_inputko .alphabet .alp10_over {
# 	top: 0;
# 	left: 234px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -360px -440px;
# }
#
# .ly_inputko .alphabet .alp11_over {
# 	top: 0;
# 	left: 260px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -400px -440px;
# }
#
# .ly_inputko .alphabet .alp12_over {
# 	top: 0;
# 	left: 286px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -440px -440px;
# }
#
# .ly_inputko .alphabet .alp13_over {
# 	top: 26px;
# 	left: 0;
# 	width: 27px;
# 	height: 27px;
# 	background-position: 0 -480px;
# }
#
# .ly_inputko .alphabet .alp14_over {
# 	top: 26px;
# 	left: 26px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -40px -480px;
# }
#
# .ly_inputko .alphabet .alp15_over {
# 	top: 26px;
# 	left: 52px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -80px -480px;
# }
#
# .ly_inputko .alphabet .alp16_over {
# 	top: 26px;
# 	left: 78px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -120px -480px;
# }
#
# .ly_inputko .alphabet .alp17_over {
# 	top: 26px;
# 	left: 104px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -160px -480px;
# }
#
# .ly_inputko .alphabet .alp18_over {
# 	top: 26px;
# 	left: 130px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -200px -480px;
# }
#
# .ly_inputko .alphabet .alp19_over {
# 	top: 26px;
# 	left: 156px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -240px -480px;
# }
#
# .ly_inputko .alphabet .alp20_over {
# 	top: 26px;
# 	left: 182px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -280px -480px;
# }
#
# .ly_inputko .alphabet .alp21_over {
# 	top: 26px;
# 	left: 208px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -320px -480px;
# }
#
# .ly_inputko .alphabet .alp22_over {
# 	top: 26px;
# 	left: 234px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -360px -480px;
# }
#
# .ly_inputko .alphabet .alp23_over {
# 	top: 26px;
# 	left: 260px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -400px -480px;
# }
#
# .ly_inputko .alphabet .alp24_over {
# 	top: 26px;
# 	left: 286px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -440px -480px;
# }
#
# .ly_inputko .alphabet .alp25_over {
# 	top: 52px;
# 	left: 0;
# 	width: 27px;
# 	height: 27px;
# 	background-position: 0 -520px;
# }
#
# .ly_inputko .alphabet .alp26_over {
# 	top: 52px;
# 	left: 26px;
# 	width: 27px;
# 	height: 27px;
# 	background-position: -40px -520px;
# }
#
# /*# sourceMappingURL=api_setkr_https.css.map */
# /*# sourceMappingURL=data:application/json;base64,... */</style><script async="" charset="utf-8" src="https://ssl.pstatic.net/tveta/libs/glad/prod/2.9.1/gfp-ext-nda.js" type="text/javascript"></script><script async="" charset="utf-8" src="https://ssl.pstatic.net/tveta/libs/glad/prod/2.9.1/gfp-ext-nda.js" type="text/javascript"></script><script async="" charset="utf-8" src="https://ssl.pstatic.net/tveta/libs/glad/prod/2.9.1/gfp-ext-nda.js" type="text/javascript"></script></head> <body> <div id="u_skip"> <a href="#newsstand"><span>뉴스스탠드 바로가기</span></a> <a href="#themecast"><span>주제별캐스트 바로가기</span></a> <a href="#timesquare"><span>타임스퀘어 바로가기</span></a> <a href="#shopcast"><span>쇼핑캐스트 바로가기</span></a> <a href="#account"><span>로그인 바로가기</span></a> </div> <div id="wrap"> <style>._1syGnXOL{padding-right:18px;font-size:14px;line-height:0;letter-spacing:-.25px;color:#000}._1syGnXOL span,._1syGnXOL strong{line-height:49px}._1syGnXOL:before{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20220527@2x.png);background-repeat:no-repeat;background-size:141px 112px;width:18px;height:18px;margin:16px 8px 0 0;background-position:-98px 0}[data-useragent*="MSIE 8"] ._1syGnXOL:before{background-image:url(https://static-whale.pstatic.net/main/sprite-20220527.png)}._1syGnXOL._3dsvmZg2:before{background-position:-47px -85px}._1syGnXOL._1NBFx1WK:before{width:20px;height:20px;margin:15px 8px 0 0;background-position:-21px -89px}._1syGnXOL._2mcQEKCd:before{width:22px;height:22px;margin:14px 7px 0 0;background-position:-47px -63px}._1syGnXOL._36slsKuJ:before{width:21px;height:49px;margin:0 14px 0 0;background-position:0 -63px}._1syGnXOL._3qlJVWzR:before{width:24px;height:49px;margin:0 10px 0 0;background-position:-117px 0}._1syGnXOL._3VkgqBXB:before{width:26px;height:49px;margin:0 10px 0 0;background-position:-116px -54px}._1syGnXOL._3di88A4c{padding-right:12px;font-size:17px}._1syGnXOL._3di88A4c:before{content:none}._1syGnXOL ._19K4X1CD{text-decoration:underline}._2aeXMlrb{display:inline-block;position:relative;font-size:12px;height:49px;width:78px;text-decoration:none;color:#fff;font-weight:700;letter-spacing:-.5px;vertical-align:top}._2aeXMlrb span{text-align:center;margin:9px 0;height:31px;display:block;line-height:31px;border-radius:15px}._2aeXMlrb span:before{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20220527@2x.png);background-repeat:no-repeat;background-size:141px 112px}[data-useragent*="MSIE 8"] ._2aeXMlrb span:before{background-image:url(https://static-whale.pstatic.net/main/sprite-20220527.png)}._2aeXMlrb.BMgpjddw{font-size:11px;width:94px}._2aeXMlrb.BMgpjddw span:before{margin:9px 3px 0 0;width:17px;height:13px;background-position:-89px -63px}._3h-N8T9V{position:absolute;top:0;left:0;right:0;bottom:0;background:rgba(0,0,0,0)}._1KncATpM{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20220527@2x.png);background-repeat:no-repeat;background-size:141px 112px;margin-top:14px;float:left;width:98px;height:21px;background-position:0 -21px}[data-useragent*="MSIE 8"] ._1KncATpM{background-image:url(https://static-whale.pstatic.net/main/sprite-20220527.png)}._1KncATpM._2v3uxv2x{background-position:0 0}._1KncATpM._1yl_Ow6o{background-position:0 -42px}._20PYt6lT{font-size:11px;height:49px;cursor:pointer;position:absolute;top:0;right:0;color:#666;opacity:.7}._20PYt6lT:after{width:15px;height:15px;margin-left:4px;background-position:-98px -33px;display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20220527@2x.png);background-repeat:no-repeat;background-size:141px 112px}[data-useragent*="MSIE 8"] ._20PYt6lT:after{background-image:url(https://static-whale.pstatic.net/main/sprite-20220527.png)}._20PYt6lT._39oMCV2N:after{background-position:-98px -18px}._20PYt6lT._3MOWOORv{color:#c3c2c2}._20PYt6 ...
# <div class="_1hiMWemA" data-clk-prefix="top" id="NM_TOP_BANNER" style="background-color: #fff7e1">
# <div class="tY_u8r23">
# <a class="_3h-N8T9V" data-clk="dropbanner1a" href="https://whale.naver.com/banner/details/security/?=main&amp;wpid=RydDy7"></a><span class="_1syGnXOL _3VkgqBXB" data-clk="dropbanner1a" style="padding-right: 20px; font-size: 17px; color: black"><span>매일 쓰는 브라우저 보안이 걱정된다면, </span><strong>안전하고 빠른 최신 브라우저 웨일로 업데이트 하세요.</strong></span><a class="_2aeXMlrb BMgpjddw" data-clk="dropdownload1a" href="https://installer-whale.pstatic.net/downloads/banner/RydDy7/WhaleSetup.exe" id="NM_whale_download_btn"><span style="background-color: #0436c7">다운로드</span></a><button class="_20PYt6lT _39oMCV2N" data-clk="dropclose1a" data-ui-cookie-exp-days="3" data-ui-cookie-key="NM_TOP_PROMOTION" data-ui-cookie-value="1" data-ui-hide-target="#NM_TOP_BANNER" type="button">
# 3일 동안 보지 않기
# </button>
# </div>
# </div>
# <div id="header" role="banner">
# <div class="special_bg">
# <div class="group_flex">
# <div class="logo_area">
# <h1 class="logo_default">
# <a class="logo_naver" data-clk="top.logo" href="/"><span class="blind">네이버</span></a>
# </h1>
# </div>
# <div class="service_area">
# <a class="link_set" data-clk="top.mkhome" href="https://help.naver.com/support/welcomePage/guide.help" id="NM_set_home_btn">네이버를 시작페이지로</a>
# <i class="sa_bar"></i>
# <a class="link_jrnaver" data-clk="top.jrnaver" href="https://jr.naver.com"><i class="ico_jrnaver"></i><span class="blind">쥬니어네이버</span></a>
# <a class="link_happybin" data-clk="top.happybean" href="https://happybean.naver.com"><i class="ico_happybin"></i><span class="blind">해피빈</span></a>
# </div>
# <div class="search_area" data-clk-prefix="sch" id="search">
# <form action="https://search.naver.com/search.naver" id="sform" method="get" name="sform" role="search">
# <fieldset>
# <legend class="blind">검색</legend>
# <select class="blind" id="where" name="where" title="검색 범위 선택">
# <option selected="selected" value="nexearch">통합검색</option><option value="post">블로그</option><option value="cafeblog">카페</option><option value="cafe">- 카페명</option><option value="article">- 카페글</option><option value="kin">지식iN</option><option value="news">뉴스</option><option value="web">사이트</option><option value="category">- 카테고리</option><option value="site">- 사이트</option><option value="movie">영화</option><option value="webkr">웹문서</option><option value="dic">사전</option><option value="100">- 백과사전</option><option value="endic">- 영어사전</option><option value="eedic">- 영영사전</option><option value="krdic">- 국어사전</option><option value="jpdic">- 일본어사전</option><option value="hanja">- 한자사전</option><option value="terms">- 용어사전</option><option value="book">책</option><option value="music">음악</option><option value="doc">전문자료</option><option value="shop">쇼핑</option><option value="local">지역</option><option value="video">동영상</option><option value="image">이미지</option><option value="mypc">내PC</option><optgroup label="스마트 파인더"><option value="movie">영화</option><option value="auto">자동차</option><option value="game">게임</option><option value="health">건강</option><option value="people">인물</option></optgroup><optgroup label="네이버 랩"><option>긍정부정검색</option></optgroup>
# </select>
# <input id="sm" name="sm" type="hidden" value="top_hty"/>
# <input id="fbm" name="fbm" type="hidden" value="0"/>
# <input disabled="disabled" id="acr" name="acr" type="hidden" value=""/>
# <input disabled="disabled" id="acq" name="acq" type="hidden" value=""/>
# <input disabled="disabled" id="qdt" name="qdt" type="hidden" value=""/>
# <input id="ie" name="ie" type="hidden" value="utf8"/>
# <input disabled="disabled" id="acir" name="acir" type="hidden" value=""/>
# <input disabled="disabled" id="os" name="os" type="hidden" value=""/>
# <input disabled="disabled" id="bid" name="bid" type="hidden" value=""/>
# <input disabled="disabled" id="pkid" name="pkid" type="hidden" value=""/>
# <input disabled="disabled" id="eid" name="eid" type="hidden" value=""/>
# <input disabled="disabled" id="mra" name="mra" type="hidden" value=""/>
# <div class="green_window" style="">
# <!-- [AU] data-atcmp-element 에 해당하는 attribute를 추가해주세요. -->
# <input accesskey="s" autocomplete="off" class="input_text" data-atcmp-element="" id="query" maxlength="255" name="query" onclick="document.getElementById('fbm').value=1;" placeholder="검색어를 입력해 주세요." style="ime-mode:active;" tabindex="1" title="검색어 입력" type="text" value=""/>
# </div>
# <button class="btn_submit" id="search_btn" onclick="window.nclick(this,'sch.action','','',event);" style="" tabindex="3" title="검색" type="submit">
# <span class="blind">검색</span>
# <span class="ico_search_submit"></span>
# </button>
# </fieldset>
# </form>
# <!-- 한글입력기 -->
# <a class="btn_keyboard" href="#" id="ke_kbd_btn" onclick="return false;" role="button"><span class="blind">한글 입력기</span><span class="ico_keyboard"></span></a>
# <div id="_nx_kbd" style="display:none;"></div>
# <div class="autocomplete">
# <!-- 자동완성 열린 경우 fold 클래스 추가, 딤드인 경우 dim 추가 -->
# <a aria-pressed="false" class="btn_arw _btn_arw fold" data-atcmp-element="" href="#" id="nautocomplete" role="button" tabindex="2"><span class="blind">자동완성 레이어</span><span class="ico_arr"></span></a>
# </div>
# <!-- 자동완성레이어 -->
# <div class="reatcmp" id="autoFrame" style="display: none;">
# <!-- [AU] data-atcmp-element attribute를 추가해주세요. -->
# <div class="ly_atcmp" data-atcmp-element="">
# <div class="api_atcmp_wrap">
# <!-- 최근검색어 -->
# <!-- [AU] _recent_layer 클래스를 추가해주세요. -->
# <div class="atcmp_fixer _recent_layer" style="display:none;">
# <!-- [AU] _recent_header 클래스를 추가해주세요. -->
# <div class="atcmp_header _recent_header">
# <strong class="tit">최근검색어</strong>
# <div class="option">
# <!-- [AU] _delAll 클래스를 추가해주세요. -->
# <a aria-pressed="false" class="item _delAll" href="#" role="button">전체삭제</a>
# </div>
# </div>
# <div class="atcmp_container">
# <!-- [AU] _recent 클래스를 추가해주세요. -->
# <ul class="kwd_lst _recent">
# <!-- 최근검색어 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="history" data-keyword="@in_txt@" attribute를 추가해주세요. -->
# <li class="item _item" data-keyword="@in_txt@" data-rank="@rank@" data-template-type="history">
# <a class="kwd" href="#">
# <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span><span>@txt@</span></span>
# </a>
# <span class="etc">
# <em class="date">@date@.</em>
# <!-- [AU] _del 클래스를 추가해주세요. -->
# <a aria-pressed="false" class="bt_item _del" href="#" role="button"><i class="imsc ico_del">삭제</i></a>
# </span>
# </li>
# </ul>
# <!-- [D] 검색어 저장 꺼진 경우 atcmp_fixer에 type_off 추가 -->
# <!-- [AU] _offMsg 클래스를 추가해주세요. -->
# <div class="kwd_info kwd_off _offMsg" style="display: none;">검색어 저장 기능이 꺼져 있습니다.<br/><span class="kwd_dsc">설정이 초기화 된다면 <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/support/alias/search/word/word_29.naver" target="_blank">도움말</a>을 확인해주세요.</span></div>
# <!-- [D] 검색어 내역 없는 경우 atcmp_fixer에 type_off 추가 -->
# <!-- [AU] _recentNone 클래스를 추가해주세요. -->
# <div class="kwd_info kwd_none _recentNone" style="display: none;">최근 검색어 내역이 없습니다.<br/><span class="kwd_dsc">설정이 초기화 된다면 <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/support/alias/search/word/word_29.naver" target="_blank">도움말</a>을 확인해주세요.</span></div>
# </div>
# <div class="atcmp_footer">
# <span class="side_opt_area">
# <span class="opt_item"><a data-clk="sly.help" href="https://help.naver.com/support/service/main.help?serviceNo=605&amp;categoryNo=1991" target="_blank">도움말</a></span>
# </span>
# <span class="rside_opt_area">
# <span class="opt_item">
# <!-- [AU] _keywordOnOff 클래스를 추가해주세요. -->
# <a class="close _keywordOnOff" href="#">자동저장 끄기</a>
# </span>
# </span>
# </div>
# </div>
# <!-- 자동완성 -->
# <!-- [AU] _atcmp_layer 클래스를 추가해주세요. -->
# <div class="atcmp_fixer _atcmp_layer" style="display:none;">
# <!-- [AU] _words 클래스를 추가해주세요. -->
# <div class="atcmp_container _words">
# <!-- 정답형 템플릿 : 로또당첨번호 -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_3" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
# <!-- 정답형 템플릿 : 환율 -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_9" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
# <!-- 정답형 템플릿 : 날씨(국내11, 해외12) -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_11" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
# <!-- 정답형 템플릿 : 사이트 바로가기 -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_17" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
# <!-- [AU] _kwd_list 클래스를 추가해주세요. -->
# <ul class="kwd_lst _kwd_list">
# <!-- [AU] 자동완성 검색어 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-rank="@rank@" data-template-type="suggestion" data-keyword="@in_txt@" attribute를 추가해주세요. -->
# <!-- [AU] 최근검색어 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-rank="@rank@" data-template-type="history" data-keyword="@in_txt@" attribute를 추가해주세요. -->
# </ul>
# <!-- [AU] 문맥검색 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-rank="@rank@" data-template-type="intend" data-keyword="@transQuery@" attribute를 추가해주세요. -->
# <!-- [D] 선거안내문구 -->
# <!-- [AU] _alert 클래스를 추가해주세요. -->
# <div class="atcmp_alert _alert">
# <div class="dsc_election">
# <p class="dsc">
# <i class="imsc ico_election"></i><span class="_alert_passage"></span>
# </p>
# <span class="dsc_inner">
# <!-- [AU] _alert_passage2 클래스를 추가해주세요. -->
# <span class="_alert_passage2"></span>
# <!-- [AU] _alert_link 클래스를 추가해주세요. -->
# <a class="link _alert_link" href="#" target="_blank">자세히보기</a>
# </span>
# </div>
# </div>
# <!-- [AU] _plus 클래스를 추가해주세요. -->
# <div class="atcmp_plus _plus">
# <div class="dsc_plus">
# <a class="link_dsc" data-clk="sug.cxhelp" href="https://help.naver.com/support/alias/search/word/word_16.naver" target="_blank">관심사를 반영한 컨텍스트 자동완성<i class="imsc ico_help">도움말</i></a>
# </div>
# <div class="switch">
# <!-- [D] 선택시 aria-pressed="ture/false" -->
# <!-- [AU] _plus_btn 클래스를 추가해주세요. -->
# <a aria-pressed="false" class="bt_switch active _plus_btn" href="#" role="button"><i class="imsc ico_option">컨텍스트 자동완성</i></a>
# </div>
# <!-- [AU] _plus_layer 클래스를 추가해주세요. -->
# <div class="layer_plus _plus_layer">
# <strong class="tit">컨텍스트 자동완성</strong>
# <!-- [AU] _plus_layer_isloggedin 클래스를 추가해주세요. -->
# <!-- [AU] style="display:none" 추가해주세요. -->
# <div class="_plus_layer_isloggedin" style="display:none">
# <p class="dsc">ON/OFF 설정은<br/>해당기기(브라우저)에 저장됩니다.</p>
# <div class="btn_area">
# <a class="btn btn_view" data-clk="sug.cxlink" href="https://help.naver.com/support/alias/search/word/word_16.naver" target="_blank">자세히</a>
# </div>
# </div>
# <!-- [AU] _plus_layer_isnotloggedin 클래스를 추가해주세요. -->
# <!-- [AU] style="display:none" 추가해주세요. -->
# <div class="_plus_layer_isnotloggedin" style="display:none">
# <p class="dsc"><em class="txt">동일한 시간대/연령/남녀별</em> 사용자 그룹의<br/>관심사에 맞춰 자동완성을 제공합니다.</p>
# <div class="btn_area">
# <a class="btn btn_login" data-clk="sug.cxlogin" href="https://nid.naver.com/nidlogin.login">로그인</a>
# <a class="btn btn_view" data-clk="sug.cxlink" href="https://help.naver.com/support/alias/search/word/word_16.naver" target="_blank">자세히</a>
# </div>
# </div>
# <!-- [AU] _plus_layer_close 클래스를 추가해주세요. -->
# <a class="btn_close _plus_layer_close" href="#" role="button"><i class="imsc ico_close">컨텍스트 자동완성 레이어 닫기</i></a>
# </div>
# </div>
# </div>
# <div class="atcmp_footer">
# <span class="side_opt_area">
# <span class="opt_item"><a data-clk="sug.help" href="https://help.naver.com/alias/search/word/word_17.naver" target="_blank">도움말</a></span>
# <span class="opt_item"><a class="report" data-clk="sug.report" href="https://help.naver.com/support/contents/contents.help?serviceNo=605&amp;categoryNo=18215" target="_blank">신고</a></span>
# </span>
# <span class="rside_opt_area">
# <span class="opt_item">
# <!-- [AU] _suggestOnOff 클래스를 추가해주세요. -->
# <a class="close _suggestOnOff" href="#">자동완성 끄기</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!--EMPTY-->
# <div id="gnb" role="navigation">
# <div class="gnb_inner" id="NM_FAVORITE">
# <div class="group_nav">
# <ul class="list_nav type_fix">
# <li class="nav_item">
# <a class="nav" data-clk="svc.mail" href="https://mail.naver.com/"><i class="ico_mail"></i>메일</a>
# </li>
# <li class="nav_item"><a class="nav" data-clk="svc.cafe" href="https://section.cafe.naver.com/">카페</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.blog" href="https://section.blog.naver.com/">블로그</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.kin" href="https://kin.naver.com/">지식iN</a></li>
# <li class="nav_item"><a class="nav shop" data-clk="svc.shopping" href="https://shopping.naver.com/"><span class="blind">쇼핑</span></a></li>
# <li class="nav_item"><a class="nav shoplive" data-clk="svc.shoppinglive" href="https://shoppinglive.naver.com/home"><span class="blind">쇼핑LIVE</span></a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.pay" href="https://order.pay.naver.com/home">Pay</a></li>
# <li class="nav_item">
# <a class="nav" data-clk="svc.tvcast" href="https://tv.naver.com/"><i class="ico_tv"></i>TV</a>
# </li>
# </ul>
# <ul class="list_nav NM_FAVORITE_LIST">
# <li class="nav_item"><a class="nav" data-clk="svc.dic" href="https://dict.naver.com/">사전</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.news" href="https://news.naver.com/">뉴스</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.stock" href="https://finance.naver.com/">증권</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.land" href="https://land.naver.com/">부동산</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.map" href="https://map.naver.com/">지도</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.vibe" href="https://vibe.naver.com/?from=naver_main&amp;utm_source=naver_main&amp;utm_medium=naver_main_pcweb&amp;utm_campaign=naver_main_redirect">VIBE</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.book" href="https://search.shopping.naver.com/book/home">도서</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.webtoon" href="https://comic.naver.com/">웹툰</a></li>
# </ul>
# <ul class="list_nav type_empty" style="display: none;"></ul>
# <a class="btn_more" data-clk="svc.more" href="#" role="button">더보기</a>
# <div class="ly_btn_area">
# <a class="btn NM_FAVORITE_ALL" data-clk="map.svcmore" href="more.html">서비스 전체보기</a>
# <a class="btn btn_set" data-clk="map.edit" href="#" role="button">메뉴설정</a>
# <a class="btn btn_reset" data-clk="edt.reset" href="#" role="button" style="display: none;">초기화</a>
# <a class="btn btn_save" data-clk="edt.save" href="#" role="button" style="display: none;">저장</a>
# </div>
# </div>
# <div class="group_weather" data-nm-ui="rolling" id="NM_WEATHER">
# <div class="eg-flick-viewport" style="position: relative; z-index: 0; overflow: hidden; min-width: 100%; height: 100%; touch-action: pan-x; user-select: none; -webkit-user-drag: none; width: 270px;"><div class="eg-flick-camera" style="width: 100%; height: 100%; will-change: transform; transform: translate3d(0px, 0px, 0px);"><div class="eg-flick-panel" style="width: 270px; position: absolute; top: 0px;">
# <a class="weather_area ico_w01" data-clk="squ.weat" href="https://weather.naver.com/today/02135103?cpName=KMA">
# ...
# <em class="theme_category"> 경제</em>
# <strong class="title elss">“알바생인데 국민연금에 가입한다고요?”</strong>
# <p class="desc">국민연금에 대해 꼭 알아야할 11가지 사실들[스페셜 리포트 : Q&amp;A] 국민연금, 세대간 전쟁의 도화선 되나 사진=게티이미지뱅크 소득이 있는 사람 대부분이 국민연금에 가입돼 있다. 하지만 정작 국민연금에 왜 가입하는지, 얼마나 보험료를 내고 있는지, 개인연금과의 차이는 무엇인지 등을 모르는 이들이 많다. 국민연금을 둘러싼 궁금증을 정리했다.Q</p>
# <div class="source_box">
# <span class="date">어제</span>
# <span class="source">
# <span class="source_inner">한경BUSINESS</span>
# </span>
# </div>
# </a>
# </li>
# <li class="theme_item" data-da-position="true" data-gdid="C3S_RANKING_https://post.naver.com/viewer/postView.naver?volumeNo=35311540&amp;memberNo=37570062&amp;vType=VERTICAL">
# <a class="theme_thumb" data-clk="tcc_fin.list11cont5" href="https://post.naver.com/viewer/postView.naver?volumeNo=35311540&amp;memberNo=37570062&amp;vType=VERTICAL" target="_blank">
# <img alt='"지금은 주식 매수할 때 아냐"…대형 IB 한 목소리로 경고' height="114" loading="lazy" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fpost.phinf%2FMjAyMzAxMzFfMjAx%2FMDAxNjc1MTM5NzU0MDg0.1Ix-9bIvO0Sky_ptY3bPDjEW3fQBh3uTuPDt9NFEwLsg.gKaL3Bpieo_Sh3C2eQPCPbk80GkeHhocGmVFDQC2mwAg.JPEG%2FIFQnLT7slB5xhoWfnUlRp_5YFtjg.jpg%22&amp;type=nf340_228" width="170"/>
# <span class="thumb_bd"></span>
# </a>
# <a class="theme_info" data-clk="tcc_fin.list11cont5" href="https://post.naver.com/viewer/postView.naver?volumeNo=35311540&amp;memberNo=37570062&amp;vType=VERTICAL" target="_blank">
# <em class="theme_category"> 경제</em>
# <strong class="title elss">"지금은 주식 매수할 때 아냐"…대형 IB 한 목소리로 경고</strong>
# <p class="desc">사진=게티이미지 미국의 투자은행(IB)들이 연달아 주식 매수를 자제하라는 경고를 내놨다. 올해 들어 미국 증시에서 상승장이 펼쳐졌지만, 이는 미 중앙은행(Fed)의 영향력을 등한시한 투자라는 분석이다.모건스탠리의 마이크 윌슨 애널리스트는 30일(현지시간) 투자자 서한에 "주식 가격이 올라가고 있다는 건 투자자들이 뭔가 놓치고 있다는 걸 증명한</p>
# <div class="source_box">
# <span class="date">20시간 전</span>
# <span class="source">
# <span class="source_inner">한국경제</span>
# </span>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="group_theme" data-block-code="PC-THEME-FINANCE-MOBILE-RANKING-DEFAULT-11" data-block-id="" data-block-type="MATERIALS" data-da="container" data-index="" data-page="6" data-template-code="MOBILE-RANKING-LIST" style="display:none">
# <div class="list_theme_wrap">
# <ul class="list_theme">
# <li class="theme_item" data-da-position="true" data-gdid="C3S_RANKING_https://post.naver.com/viewer/postView.naver?memberNo=7322715&amp;volumeNo=35310174">
# <a class="theme_thumb" data-clk="tcc_fin.list12cont1" href="https://post.naver.com/viewer/postView.naver?memberNo=7322715&amp;volumeNo=35310174" target="_blank">
# <img alt="서울 택시 심야할증 기본요금 6700원" height="114" loading="lazy" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fpost.phinf%2FMjAyMzAxMzFfMTIg%2FMDAxNjc1MTMwMjk5Nzc2.ytn_MxpP3WQRW0lbtP-s5TDE3Ugdh5MO-ed34MdWxjcg.Yl7_jNPAKTSQo3s-o5Ipx1syT0tMIVBiigjFxRjlINIg.JPEG%2FIgs1KFL49D14TECTi-T1zeu-W-xU.jpg%3Ftype%3Df339_222_q90%22&amp;type=nf340_228" width="170"/>
# <span class="thumb_bd"></span>
# </a>
# <a class="theme_info" data-clk="tcc_fin.list12cont1" href="https://post.naver.com/viewer/postView.naver?memberNo=7322715&amp;volumeNo=35310174" target="_blank">
# <em class="theme_category"> 경제</em>
# <strong class="title elss">서울 택시 심야할증 기본요금 6700원</strong>
# <p class="desc">내일 택시 기본요금 1000원 올라 지하철-버스는 4월 인상 추진 吳시장 “정부 지원땐 인상폭 조정” 기재부 “입장 밝히는것 적절치 않아”오세훈 서울시장(사진)이 지하철·시내버스 요금 인상과 관련해 “고육지책으로 이해해 달라”며 강행 의사를 30일 밝혔다. 서울시는 </p>
# <div class="source_box">
# <span class="date">어제</span>
# <span class="source">
# <span class="source_inner">부자동</span>
# </span>
# </div>
# </a>
# </li>
# <li class="theme_item" data-da-position="true" data-gdid="C3S_RANKING_https://post.naver.com/viewer/postView.naver?memberNo=18265860&amp;volumeNo=35318433">
# <a class="theme_thumb" data-clk="tcc_fin.list12cont2" href="https://post.naver.com/viewer/postView.naver?memberNo=18265860&amp;volumeNo=35318433" target="_blank">
# <img alt="22년 4분기 맥도날드 (MCD) 실적 증가!! 인플레이션에 지친 고객들이 레스토랑으로" height="114" loading="lazy" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fpost.phinf%2FMjAyMzAxMzFfMTM1%2FMDAxNjc1MTczNTk4MTI2.3aPaa1LGShEccGi0GHdbxAVD3_NIrdDU0CuWu8eiDo0g.bDIwOPItwg1B0uTHe_3i-EIPnBBdwIZfNwQg_w92Fhkg.PNG%2FIFD_CEr0c9osVoYk5XIPBiHuptSU.jpg%3Ftype%3Df339_222_q90%22&amp;type=nf340_228" width="170"/>
# <span class="thumb_bd"></span>
# </a>
# <a class="theme_info" data-clk="tcc_fin.list12cont2" href="https://post.naver.com/viewer/postView.naver?memberNo=18265860&amp;volumeNo=35318433" target="_blank">
# <em class="theme_category"> 경제</em>
# <strong class="title elss">22년 4분기 맥도날드 (MCD) 실적 증가!! 인플레이션에 지친 고객들이 레스토랑으로</strong>
# <p class="desc">MCD 수익: 맥도날드의 4분기 전년동기대비 매출은 12.6% 증가했습니다. 이익은 증가합니다 패스트푸드 체인 맥도날드 코퍼레이션(NYSE: MCD)은 화요일 매출이 대체로 변동이 없었던 2022년 4분기 조정 수익이 증가했다고 보고했습니다. 2분기 연속으로 미국내 트래픽 증가에 주목하여 업계 동향을 거스르고 있습니다. 많은 소비자들이 인플레</p>
# <div class="source_box">
# <span class="date">15시간 전</span>
# <span class="source">
# <span class="source_inner">Master Your Space</span>
# </span>
# </div>
# </a>
# </li>
# <li class="theme_item" data-da-position="true" data-gdid="C3S_RANKING_https://post.naver.com/viewer/postView.naver?memberNo=25386652&amp;volumeNo=35309092">
# <a class="theme_thumb" data-clk="tcc_fin.list12cont3" href="https://post.naver.com/viewer/postView.naver?memberNo=25386652&amp;volumeNo=35309092" target="_blank">
# <img alt="진흙속의 진주 노량진 뉴타운, 드디어 사업 추진 본격화 됩니다!" height="114" loading="lazy" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fpost.phinf%2FMjAyMzAxMzFfMTgy%2FMDAxNjc1MTI1MjY3ODEx.eeOsj8Af1FTmmHLWeL-AxCB-5oRzxDCpuGKzZcx8udsg.HpbvBauY1kdFMfSQcJx06okXDCSsHHpVrMkl0oOjrQMg.JPEG%2FIOO80HBmk_faWmN77Il0u3IsCKyA.jpg%3Ftype%3Df339_222_q90%22&amp;type=nf340_228" width="170"/>
# <span class="thumb_bd"></span>
# </a>
# <a class="theme_info" data-clk="tcc_fin.list12cont3" href="https://post.naver.com/viewer/postView.naver?memberNo=25386652&amp;volumeNo=35309092" target="_blank">
# <em class="theme_category"> 경제</em>
# <strong class="title elss">진흙속의 진주 노량진 뉴타운, 드디어 사업 추진 본격화 됩니다!</strong>
# <p class="desc">수산시장과 고시생들의 터전 노량진… 황금 주거지로 거듭난다아실 분들은 아시겠지만 흔히 서울 재개발 3대장을 이야기할 때 한남뉴타운, 흑석뉴타운, 성수전략정비구역이 꼽히는데요. 이들 3대장에 끼진 못하지만, 못지 않게 스포트라이트를 받는 곳이 있습니다. 고시생들의 터전이자 수산시장으로 익히 알려진 노량진뉴타운입니다. 한강 이남의 마지막 알짜 입지</p>
# <div class="source_box">
# <span class="date">어제</span>
# <span class="source">
# <span class="source_inner">RealCast</span>
# </span>
# </div>
# </a>
# </li>
# <li class="theme_item" data-da-position="true" data-gdid="C3S_RANKING_https://post.naver.com/viewer/postView.naver?memberNo=38946978&amp;volumeNo=35255752">
# <a class="theme_thumb" data-clk="tcc_fin.list12cont4" href="https://post.naver.com/viewer/postView.naver?memberNo=38946978&amp;volumeNo=35255752" target="_blank">
# <img alt="2023년 변경되는 주택금융제도 살펴보기" height="114" loading="lazy" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fpost.phinf%2FMjAyMzAxMjZfMTky%2FMDAxNjc0Njk1NTM2MzA5.NgFdEWW7xku-UMK-IvettBfIQxwX2Ix9vTr1_XyywvYg.NBwmh1sitw0HWEehVKEpGpGag5hTTPAst1tEUx6I4ccg.PNG%2FID2C5ON9kioqbUzxJ-rNCu3m_O8k.jpg%3Ftype%3Df339_222_q90%22&amp;type=nf340_228" width="170"/>
# <span class="thumb_bd"></span>
# </a>
# <a class="theme_info" data-clk="tcc_fin.list12cont4" href="https://post.naver.com/viewer/postView.naver?memberNo=38946978&amp;volumeNo=35255752" target="_blank">
# <em class="theme_category"> 경제</em>
# <strong class="title elss">2023년 변경되는 주택금융제도 살펴보기</strong>
# <p class="desc">작년 하반기부터 주택정책의 주요한 특징은 주택시장 경착륙 방지를 위해 그동안 강화된 규제를 완화하는 데 초점을 두고 있습니다. 특히 주택금융제도 측면에서는 LTV 규제 완화, 규제지역 해제 확대 등으로 주택 구입 여건을 개선하는 정책들이 시행되었습니다. 이는 최근의 기준금리 인상에 따른 주택 수요가 급격히 위축됨에 따라 시장 정상화를 위한 조치들로 해석될 </p>
# <div class="source_box">
# <span class="date">6일 전</span>
# <span class="source">
# <span class="source_inner">우리은행</span>
# </span>
# </div>
# </a>
# </li>
# <li class="theme_item" data-da-position="true" data-gdid="C3S_RANKING_https://post.naver.com/viewer/postView.naver?memberNo=12282441&amp;volumeNo=35311814">
# <a class="theme_thumb" data-clk="tcc_fin.list12cont5" href="https://post.naver.com/viewer/postView.naver?memberNo=12282441&amp;volumeNo=35311814" target="_blank">
# <img alt="노숙인에 명의 넘겨 ‘깡통전세’…361억원 꿀꺽한 일당 검거" height="114" loading="lazy" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fpost.phinf%2FMjAyMzAxMzFfMzIg%2FMDAxNjc1MTQxMjEyMTM1.ir9N0P5oWkVS538Mm9mHHHebgyI2dPFidB48OQaxhFsg.v5ls2NTrGlsQZHkfmoaM6RX-7-ghHUsngDqRCfIbi3Mg.JPEG%2FIjvsE9CdzMHdC2F_jjOKLoR6K6J8.jpg%3Ftype%3Df339_222_q90%22&amp;type=nf340_228" width="170"/>
# <span class="thumb_bd"></span>
# </a>
# <a class="theme_info" data-clk="tcc_fin.list12cont5" href="https://post.naver.com/viewer/postView.naver?memberNo=12282441&amp;volumeNo=35311814" target="_blank">
# <em class="theme_category"> 경제</em>
# <strong class="title elss">노숙인에 명의 넘겨 ‘깡통전세’…361억원 꿀꺽한 일당 검거</strong>
# <p class="desc">임차인(세입자) 몰래 노숙자나 신용불량자 등에게 명의를 넘기는 수법으로 양산한 빌라 152채의 임대차 보증금 361억원을 속여 뺏은 ‘깡통전세 사기’ 조직 113명이 적발됐다. 이들은 주로 전세 매매 등의 경험이 부족한 신혼부부나 사회 초년생 등을 노렸던 것으로 조사됐다. 부산경찰청은 전세 사기 조직 113명을 검거해 부</p>
# <div class="source_box">
# <span class="date">어제</span>
# <span class="source">
# <span class="source_inner">국민일보</span>
# </span>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="btn_more_wrap">
# <button class="btn_more" data-clk-custom="tcc_fin.more" data-next-page="2" type="button"><i class="ico_more"></i>새로운 글 더보기</button>
# </div>
# </div>
# </div>
# </div> </div> <div class="column_right" id="NM_INT_RIGHT"> <div class="column_fix_wrap"> <div id="da_brand"></div>
# <div class="sc_login" id="account">
# <h2 class="blind">로그인</h2>
# <p class="login_msg">네이버를 더 안전하고 편리하게 이용하세요</p>
# <a class="link_login" data-clk="log_off.login" href="https://nid.naver.com/nidlogin.login?mode=form&amp;url=https%3A%2F%2Fwww.naver.com"><i class="ico_naver"><span class="blind">네이버</span></i>로그인</a>
# <div class="sub_area">
# <div class="look_box">
# <a class="link_look" data-clk="log_off.searchid" href="https://nid.naver.com/user/help.nhn?todo=idinquiry">아이디</a>
# <a class="link_look" data-clk="log_off.searchpass" href="https://nid.naver.com/nidreminder.form">비밀번호찾기</a>
# </div>
# <a class="link_join" data-clk="log_off.registration" href="https://nid.naver.com/nidregister.form?url=https%3A%2F%2Fwww.naver.com">회원가입</a>
# </div>
# </div>
# <div class="sc_timesquare" id="timesquare"> <h2 class="blind">타임스퀘어</h2> <div class="card_wrap">
# <div class="card_nav">
# <a class="btn_nav btn_prev" data-clk="squ.pre" href="#" role="button"><span class="blind">이전</span></a>
# <a class="btn_nav btn_next" data-clk="squ.next" href="#" role="button"><span class="blind">다음</span></a>
# </div>
# <div data-nm-ui="rolling" id="NM_TS_ROLLING_WRAP" style="height: 100%;">
# <div class="eg-flick-viewport" style="position: relative; z-index: 0; overflow: hidden; min-height: 100%; width: 100%; touch-action: pan-y; user-select: none; -webkit-user-drag: none; height: 47px;"><div class="eg-flick-camera" style="width: 100%; height: 100%; will-change: transform; transform: translate3d(0px, 0px, 0px);"><div class="eg-flick-panel" style="width: 281px; position: absolute; left: 0px;">
# <a class="card_stock" data-clk="squ.kosdaq" href="https://finance.naver.com/sise/sise_index.nhn?code=KOSDAQ">
# <strong class="stock_title">증시</strong>
# <div class="stock_box">
# <em class="name">코스닥</em>
# <strong class="current">750.18</strong>
# <span class="rate rate_up"><span class="blind">상승</span>9.69 +1.31%</span>
# </div>
# </a>
# </div></div></div></div>
# </div> <!-- EMPTY --> </div> <div id="veta_branding"> <span class="blind"> <script id="veta_service_check" src="https://siape.veta.naver.com/fxshow?su=SU10803&amp;nrefreshx=0"></script> </span> <div id="veta_branding_inner" style="width:350px;height:200px"><div style="width: 350px; height: 200px; margin: 0px auto; position: relative;"><iframe frameborder="no" id="veta_branding_inner_tgtLREC" name="" scrolling="no" style="width: 350px; height: 200px; visibility: inherit; border: 0px; vertical-align: bottom; position: absolute;" tabindex="0" title="AD"></iframe></div></div> <span class="veta_bd_t"></span> <span class="veta_bd_b"></span> <span class="veta_bd_l"></span> <span class="veta_bd_r"></span> </div> <div class="sc_shopcast" id="shopcast"> <iframe frameborder="0" height="1809" id="shopcast_iframe" marginheight="0" marginwidth="0" scrolling="no" src="/shoppingbox/shoppingboxnew/main.nhn?mode=plusdeal&amp;domain=N" title="쇼핑캐스트" width="350"></iframe> </div> </div> </div> <a class="content_top" href="#wrap" id="NM_scroll_top_btn"><span class="blind">TOP</span></a> <button aria-pressed="false" class="btn_theme" id="NM_darkmode_btn" role="button" type="button"> <span class="blind">라이트 모드로 보기</span> </button> </div> <div id="footer" role="contentinfo"> <div class="footer_inner"> <div class="banner_area" id="NM-FOOTER-AD"> <div class="da_box_wrap"> <div id="da_public_left"> <div style="width: 350px; height: 86px; border: 0pt none;"><iframe frameborder="no" height="86" id="da_public_left_tgtLREC" scrolling="no" src="https://siape.veta.naver.com/fxshow?su=SU10641&amp;nrefreshx=0#frameId=da_public_left_tgtLREC&amp;origin=https%3A%2F%2Fwww.naver.com&amp;msgToken=1966322560.3435543&amp;isFluid=false&amp;runtime=NDPSDK" style="border: 0px; vertical-align: bottom;" tabindex="-1" width="350"></iframe></div></div> <div id="da_public_right"> <div style="width: 350px; height: 86px; border: 0pt none;"><iframe frameborder="no" height="86" id="da_public_right_tgtLREC" scrolling="no" src="https://siape.veta.naver.com/fxshow?su=SU10642&amp;nrefreshx=0#frameId=da_public_right_tgtLREC&amp;origin=https%3A%2F%2Fwww.naver.com&amp;msgToken=2637616486.8451834&amp;isFluid=false&amp;runtime=NDPSDK" style="border: 0px; vertical-align: bottom;" tabindex="-1" width="350"></iframe></div></div> <div id="veta_time2"> <div style="width: 350px; height: 86px; border: 0pt none;"><iframe frameborder="no" height="86" id="veta_time2_tgtLREC" scrolling="no" src="https://siape.veta.naver.com/fxshow?su=SU10640&amp;nrefreshx=0#frameId=veta_time2_tgtLREC&amp;origin=https%3A%2F%2Fwww.naver.com&amp;msgToken=2341296932.5883646&amp;isFluid=false&amp;runtime=NDPSDK" style="border: 0px; vertical-align: bottom;" tabindex="-1" width="350"></iframe></div></div> </div> </div> <div class="notice_area" data-clk-prefix="ntc"> <div class="notice_box"> <h3 class="title"><a href="https://www.naver.com/NOTICE">공지사항</a> </h3> <!-- EMPTY --> </div> <a class="link_all" data-clk="svcmap" href="more.html">서비스 전체보기</a> </div> <div class="aside_area"> <div class="partner_box_wrap"> <div class="partner_box" data-clk-prefix="crt"> <h3 class="title">Creators</h3> <a class="link_partner" data-clk="creator" href="https://www.navercorp.com/service/creators">크리에이터</a> <a class="link_partner" data-clk="smbusiness" href="https://www.navercorp.com/service/business">스몰비즈니스</a> </div> <div class="partner_box" data-clk-prefix="crt"> <h3 class="title">Partners</h3> <a class="link_partner" data-clk="sme" href="https://campaign.naver.com/smefullcare/online/">SME 풀케어 시스템</a> <a class="link_partner" data-clk="service" href="https://business.naver.com/service.html">비즈니스 · 광고</a> <a class="link_partner" data-clk="store" href="https://sell.storefarm.naver.com/#/home/about">스토어 개설</a> <a class="link_partner" data-clk="place" href="https://smartplace.naver.com">지역업체 등록</a> <a class="link_partner" data-clk="expert" href="https://expert.naver.com/expert/introduction?tab=guide#join">엑스퍼트 등록</a> </div> <div class="partner ...
# </body></html>

# %%
# html에서 데이터 가져오기 (연습)
# 중요 키워드 : tag, id, class
# tag : 여러개의 tag이름이 있을 수 있다
# id : 고유한 값만 가짐
# class : 여러개 값을 가질 수 있음

# %%
html = """<html>
            <head>
                <title>브라우저 탭 제목은 이곳에 작성</title>
            </head>
            <body>
                <p>body 태그 시작과 끝 사이에 있는 모든것이
                   브라우저에 보이는 부분</p>
                <h1>우리 동네 시장</h1>
                <div class="sale">
                    <p id="fruits1" class="fruits">
                        <span class = "name"> 바나나 </span>
                        <span class = "price"> 3000원 </span>
                        <span class = "inventory"> 500개 </span>
                        <span class = "store"> 가나다상회 </span>
                        <a href = "http://www.naver.com">홈페이지[1]</a>
                    </p>
                </div>
                <div class="prepare">
                    <p id="fruits2" class="fruits">
                        <span class = "name"> 파인애플 </span>
                        <span class = "price"> 10,000원 </span>
                        <span class = "inventory"> 300개 </span>
                        <span class = "store"> 파인상회 </span>
                        <a href = "http://www.daum.net">홈페이지[2]</a>
                    </p>
                </div>
            </body>
          </html>"""

# %%
# html 형태로 변환
# html 형태로 변환
soup = BeautifulSoup(html,"html.parser")
soup
# Out:
# <html>
# <head>
# <title>브라우저 탭 제목은 이곳에 작성</title>
# </head>
# <body>
# <p>body 태그 시작과 끝 사이에 있는 모든것이
#                    브라우저에 보이는 부분</p>
# <h1>우리 동네 시장</h1>
# <div class="sale">
# <p class="fruits" id="fruits1">
# <span class="name"> 바나나 </span>
# <span class="price"> 3000원 </span>
# <span class="inventory"> 500개 </span>
# <span class="store"> 가나다상회 </span>
# <a href="http://www.naver.com">홈페이지[1]</a>
# </p>
# </div>
# <div class="prepare">
# <p class="fruits" id="fruits2">
# <span class="name"> 파인애플 </span>
# <span class="price"> 10,000원 </span>
# <span class="inventory"> 300개 </span>
# <span class="store"> 파인상회 </span>
# <a href="http://www.daum.net">홈페이지[2]</a>
# </p>
# </div>
# </body>
# </html>

# %%
# 태그 이름을 이용해서 조회
# 문서 안에서 span이라는 이름의 태그 조회
# tag는 앞뒤로 아무런 기호가 안붙는다
# id는 왼쪽에 #을 붙임
# class는 왼쪽에 .을 붙임
tags_span = soup.select("span")
tags_span

tags_p = soup.select("p")
tags_p
# Out:
# [<p>body 태그 시작과 끝 사이에 있는 모든것이
#                     브라우저에 보이는 부분</p>,
#  <p class="fruits" id="fruits1">
#  <span class="name"> 바나나 </span>
#  <span class="price"> 3000원 </span>
#  <span class="inventory"> 500개 </span>
#  <span class="store"> 가나다상회 </span>
#  <a href="http://www.naver.com">홈페이지[1]</a>
#  </p>,
#  <p class="fruits" id="fruits2">
#  <span class="name"> 파인애플 </span>
#  <span class="price"> 10,000원 </span>
#  <span class="inventory"> 300개 </span>
#  <span class="store"> 파인상회 </span>
#  <a href="http://www.daum.net">홈페이지[2]</a>
#  </p>]

# %%
# id로 접근하기 : #을 이용
ids_fruits1 = soup.select("#fruits1")
ids_fruits1
# Out:
# [<p class="fruits" id="fruits1">
#  <span class="name"> 바나나 </span>
#  <span class="price"> 3000원 </span>
#  <span class="inventory"> 500개 </span>
#  <span class="store"> 가나다상회 </span>
#  <a href="http://www.naver.com">홈페이지[1]</a>
#  </p>]

# %%
# class로 접근하기
class_price = soup.select(".price")
class_price
# Out:
# [<span class="price"> 3000원 </span>, <span class="price"> 10,000원 </span>]

# %%
# class로 접근하기
class_price = soup.select("#fruits1 .price")
class_price
# Out:
# [<span class="price"> 3000원 </span>]

# %%
#
tag = soup.select("#fruits1 span.name")
tag
# Out:
# [<span class="name"> 바나나 </span>]

# %%
tags = soup.select("div.sale > #fruits1 > span.name")
tags
# Out:
# [<span class="name"> 바나나 </span>]

# %%
tags = soup.select("div.sale span.name")
tags
# Out:
# [<span class="name"> 바나나 </span>]

# %%
tags = soup.select("div.sale")
tags
# Out:
# [<div class="sale">
#  <p class="fruits" id="fruits1">
#  <span class="name"> 바나나 </span>
#  <span class="price"> 3000원 </span>
#  <span class="inventory"> 500개 </span>
#  <span class="store"> 가나다상회 </span>
#  <a href="http://www.naver.com">홈페이지[1]</a>
#  </p>
#  </div>]

# %%
tags = soup.select("span.name")
tags[0].text
# Out:
# ' 바나나 '

# %%
for key in tags:
    print(key.text)
# Out:
#  바나나
#  파인애플

# %%
for i in range(len(tags)):
    print(tags[i].text)
# Out:
#  바나나
#  파인애플

# %%
soup
# Out:
# <html>
# <head>
# <title>브라우저 탭 제목은 이곳에 작성</title>
# </head>
# <body>
# <p>body 태그 시작과 끝 사이에 있는 모든것이
#                    브라우저에 보이는 부분</p>
# <h1>우리 동네 시장</h1>
# <div class="sale">
# <p class="fruits" id="fruits1">
# <span class="name"> 바나나 </span>
# <span class="price"> 3000원 </span>
# <span class="inventory"> 500개 </span>
# <span class="store"> 가나다상회 </span>
# <a href="http://www.naver.com">홈페이지[1]</a>
# </p>
# </div>
# <div class="prepare">
# <p class="fruits" id="fruits2">
# <span class="name"> 파인애플 </span>
# <span class="price"> 10,000원 </span>
# <span class="inventory"> 300개 </span>
# <span class="store"> 파인상회 </span>
# <a href="http://www.daum.net">홈페이지[2]</a>
# </p>
# </div>
# </body>
# </html>

# %%
tags = soup.select("a")
tags
# Out:
# [<a href="http://www.naver.com">홈페이지[1]</a>,
#  <a href="http://www.daum.net">홈페이지[2]</a>]

# %%
# 각 태그 갖고오기
# 속성값들은 딕셔너리 형태로 반환
temp = tags[0]
temp
# Out:
# <a href="http://www.naver.com">홈페이지[1]</a>

# %%
temp["href"]
# Out:
# 'http://www.naver.com'

# %%
# 웹드라이브 반환
driver.quit()

# %%
# 크롬드라이버 다운 - 버전 주의
# 프로그램에서 실행
file_path = "c:/ChromeDriver_exe/chrome_109_driver.exe"
driver = webdriver.Chrome(file_path)

# %%
# 조회할 주소 
url = "http://www.melon.com/chart/index.htm"
driver.get(url)

html = driver.page_source
soup = BeautifulSoup(html,"html.parser")

# soup

# 제목 뽑기
titles = soup.select("tr div.ellipsis.rank01 > span > a")[0:10]
# print(titles)

# 가수 뽑기
singers = soup.select("tr div.ellipsis.rank02 > a")[0:10]
#print(singers)

for i in range(len(titles)):
    print(titles[i].text," | ", singers[i].text)
    
# 웹드라이브 반환
driver.quit()
# Out:
# Ditto  |  NewJeans
# OMG  |  NewJeans
# Hype boy  |  NewJeans
# 사건의 지평선  |  윤하 (YOUNHA)
# VIBE (feat. Jimin of BTS)  |  태양
# Sugar Rush Ride  |  투모로우바이투게더
# ANTIFRAGILE  |  LE SSERAFIM (르세라핌)
# Attention  |  NewJeans
# 사랑은 늘 도망가  |  임영웅
# After LIKE  |  IVE (아이브)

# %%
print(titles)
# Out:
# [<a href="javascript:melon.play.playSong('1000002721',35945927);" title="Ditto 재생">Ditto</a>, <a href="javascript:melon.play.playSong('1000002721',35985167);" title="OMG 재생">OMG</a>, <a href="javascript:melon.play.playSong('1000002721',35454426);" title="Hype boy 재생">Hype boy</a>, <a href="javascript:melon.play.playSong('1000002721',36034936);" title="VIBE (feat. Jimin of BTS) 재생">VIBE (feat. Jimin of BTS)</a>, <a href="javascript:melon.play.playSong('1000002721',34819473);" title="사건의 지평선 재생">사건의 지평선</a>, <a href="javascript:melon.play.playSong('1000002721',36078777);" title="Sugar Rush Ride 재생">Sugar Rush Ride</a>, <a href="javascript:melon.play.playSong('1000002721',35729104);" title="ANTIFRAGILE 재생">ANTIFRAGILE</a>, <a href="javascript:melon.play.playSong('1000002721',35454425);" title="Attention 재생">Attention</a>, <a href="javascript:melon.play.playSong('1000002721',34061322);" title="사랑은 늘 도망가 재생">사랑은 늘 도망가</a>, <a href="javascript:melon.play.playSong('1000002721',35546497);" title="After LIKE 재생">After LIKE</a>]

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

file_path = "c:/ChromeDriver_exe/chrome_109_driver.exe"
driver = webdriver.Chrome(file_path)
url = "http://www.melon.com/chart/index.htm"
driver.get(url)

titles = driver.find_elements(By.CSS_SELECTOR,
                             "tr div.ellipsis.rank01 > span > a")[0:10]
singers = driver.find_elements(By.CSS_SELECTOR,
                             "tr div.ellipsis.rank02 > a")[0:10]

#print(singers[0].text)
# for i in range(len(titles)):
#     print(titles[i].text, singers[i].text, sep=" | ")
# for title, singer in zip(titles, singers):
#     print(title.text, singer.text, sep=" | ")

melon_list = []
rank = 0
for title, singer in zip(titles, singers):
    rank+=1
    
    dict = {'no':rank,'title':title.text,'singer':singer.text}
    melon_list.append(dict)
    dict = {}
print(melon_list)
time.sleep(3)

driver.quit()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_15708\3704685783.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(file_path)
# [{'no': 1, 'title': 'Ditto', 'singer': 'NewJeans'}, {'no': 2, 'title': 'OMG', 'singer': 'NewJeans'}, {'no': 3, 'title': 'Hype boy', 'singer': 'NewJeans'}, {'no': 4, 'title': '사건의 지평선', 'singer': '윤하 (YOUNHA)'}, {'no': 5, 'title': 'VIBE (feat. Jimin of BTS)', 'singer': '태양'}, {'no': 6, 'title': 'Sugar Rush Ride', 'singer': '투모로우바이투게더'}, {'no': 7, 'title': 'ANTIFRAGILE', 'singer': 'LE SSERAFIM (르세라핌)'}, {'no': 8, 'title': 'Attention', 'singer': 'NewJeans'}, {'no': 9, 'title': '사랑은 늘 도망가', 'singer': '임영웅'}, {'no': 10, 'title': 'After LIKE', 'singer': 'IVE (아이브)'}]

# %%
melon_list
# Out:
# [{'no': 1, 'title': 'Ditto', 'singer': 'NewJeans'},
#  {'no': 2, 'title': 'OMG', 'singer': 'NewJeans'},
#  {'no': 3, 'title': 'Hype boy', 'singer': 'NewJeans'},
#  {'no': 4, 'title': '사건의 지평선', 'singer': '윤하 (YOUNHA)'},
#  {'no': 5, 'title': 'VIBE (feat. Jimin of BTS)', 'singer': '태양'},
#  {'no': 6, 'title': 'Sugar Rush Ride', 'singer': '투모로우바이투게더'},
#  {'no': 7, 'title': 'ANTIFRAGILE', 'singer': 'LE SSERAFIM (르세라핌)'},
#  {'no': 8, 'title': 'Attention', 'singer': 'NewJeans'},
#  {'no': 9, 'title': '사랑은 늘 도망가', 'singer': '임영웅'},
#  {'no': 10, 'title': 'After LIKE', 'singer': 'IVE (아이브)'}]
