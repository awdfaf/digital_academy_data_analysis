# %%
### 라이브러리 정의하기
import pandas as pd
import matplotlib.pyplot as plt
import urllib.request
from gensim.models.word2vec import Word2Vec
## gensim 깨져서 오류나면 밑에 형태소 분석 객체 생성하기 할때 위에 임포트 주석처리하고 다시 돌리니까 오류 해결
from konlpy.tag import Okt

# %%
### 데이터수집
# - 네이버 영화 리뷰 데이터 다운로드하기
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings.txt",
                           filename="naver_ratings.txt")
# Out:
# ('naver_ratings.txt', <http.client.HTTPMessage at 0x1b009202fa0>)

# %%
### 다운로드 받은 파일을 데이터프레임으로 읽어 들이기
train_data = pd.read_table("./naver_ratings.txt")
train_data.head()
# Out:
#          id                                           document  label
# 0   8112052                                어릴때보고 지금다시봐도 재밌어요ㅋㅋ      1
# 1   8132799  디자인을 배우는 학생으로, 외국디자이너와 그들이 일군 전통을 통해 발전해가는 문화산...      1
# 2   4655635               폴리스스토리 시리즈는 1부터 뉴까지 버릴께 하나도 없음.. 최고.      1
# 3   9251303  와.. 연기가 진짜 개쩔구나.. 지루할거라고 생각했는데 몰입해서 봤다.. 그래 이런...      1
# 4  10067386                        안개 자욱한 밤하늘에 떠 있는 초승달 같은 영화.      1

# %%
### 데이터프레임 정보확인하기
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        200000 non-null  int64
#  1   document  199992 non-null  object
#  2   label     200000 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 4.6+ MB

# %%
### 결측치 처리하기
# 결측치가 있는 모든 행 삭제하기
train_data = train_data.dropna(how = "any")
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199992 entries, 0 to 199999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        199992 non-null  int64
#  1   document  199992 non-null  object
#  2   label     199992 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 6.1+ MB

# %%
### 데이터양을 줄여서 진행 (속도 때문에)
# 100개의 행만 사용...
train_data = train_data.iloc[:100, :]
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        100 non-null    int64
#  1   document  100 non-null    object
#  2   label     100 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 3.1+ KB

# %%
### 데이터 확인
train_data
# Out:
#           id                                           document  label
# 0    8112052                                어릴때보고 지금다시봐도 재밌어요ㅋㅋ      1
# 1    8132799  디자인을 배우는 학생으로, 외국디자이너와 그들이 일군 전통을 통해 발전해가는 문화산...      1
# 2    4655635               폴리스스토리 시리즈는 1부터 뉴까지 버릴께 하나도 없음.. 최고.      1
# 3    9251303  와.. 연기가 진짜 개쩔구나.. 지루할거라고 생각했는데 몰입해서 봤다.. 그래 이런...      1
# 4   10067386                        안개 자욱한 밤하늘에 떠 있는 초승달 같은 영화.      1
# ..       ...                                                ...    ...
# 95   3908729                               진짜 최고다 최고 성룡형님 마이 우상      1
# 96   6318878    amy6250 당신이 좋아하는 장르는 뭐요? 이영화에도 저영화에도 이런장르는 싫다니원      1
# 97   2620222                                     지금까지 본영화중에 최고다      1
# 98   5954450             매회리타가자꾸거슬려서죽었으면좋겠다고생각했는데ㅠㅠ죄책감에나도잠못이룬다.      1
# 99   9754970  어릴 때보고 커서 다시 봤는데. 진짜 잘 만든 영화였네. 웃음과 감동을 잘 이어 붙...      1
#
# [100 rows x 3 columns]

# %%
### 정제처리 하기
# - 한글을 제외한 모든 것 제외시키기
# - 한글 : ㄱ-ㅎ  가-힣  (한글 범위 전체를 의미)
## regex : 정규표현식을 쓸 것인지 여부, 첫번째를 두번째로 바꾸면서 이를 기준으로
## 첫번째 인자에 마지막에 띄어쓰기 포함해야 띄어쓰기가 사라지지 않음
train_data["document"] = \
            train_data["document"].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]",
                                               "",
                                               regex = True)
train_data
# Out:
#           id                                           document  label
# 0    8112052                                어릴때보고 지금다시봐도 재밌어요ㅋㅋ      1
# 1    8132799  디자인을 배우는 학생으로 외국디자이너와 그들이 일군 전통을 통해 발전해가는 문화산업...      1
# 2    4655635                   폴리스스토리 시리즈는 부터 뉴까지 버릴께 하나도 없음 최고      1
# 3    9251303   와 연기가 진짜 개쩔구나 지루할거라고 생각했는데 몰입해서 봤다 그래 이런게 진짜 영화지      1
# 4   10067386                         안개 자욱한 밤하늘에 떠 있는 초승달 같은 영화      1
# ..       ...                                                ...    ...
# 95   3908729                               진짜 최고다 최고 성룡형님 마이 우상      1
# 96   6318878             당신이 좋아하는 장르는 뭐요 이영화에도 저영화에도 이런장르는 싫다니원      1
# 97   2620222                                     지금까지 본영화중에 최고다      1
# 98   5954450              매회리타가자꾸거슬려서죽었으면좋겠다고생각했는데ㅠㅠ죄책감에나도잠못이룬다      1
# 99   9754970  어릴 때보고 커서 다시 봤는데 진짜 잘 만든 영화였네 웃음과 감동을 잘 이어 붙였고...      1
#
# [100 rows x 3 columns]

# %%
train_data["document"]
# Out:
# 0                                   어릴때보고 지금다시봐도 재밌어요ㅋㅋ
# 1     디자인을 배우는 학생으로 외국디자이너와 그들이 일군 전통을 통해 발전해가는 문화산업...
# 2                      폴리스스토리 시리즈는 부터 뉴까지 버릴께 하나도 없음 최고
# 3      와 연기가 진짜 개쩔구나 지루할거라고 생각했는데 몰입해서 봤다 그래 이런게 진짜 영화지
# 4                            안개 자욱한 밤하늘에 떠 있는 초승달 같은 영화
#                             ...
# 95                                 진짜 최고다 최고 성룡형님 마이 우상
# 96               당신이 좋아하는 장르는 뭐요 이영화에도 저영화에도 이런장르는 싫다니원
# 97                                       지금까지 본영화중에 최고다
# 98                매회리타가자꾸거슬려서죽었으면좋겠다고생각했는데ㅠㅠ죄책감에나도잠못이룬다
# 99    어릴 때보고 커서 다시 봤는데 진짜 잘 만든 영화였네 웃음과 감동을 잘 이어 붙였고...
# Name: document, Length: 100, dtype: object

# %%
### 단어 토큰화 하기
# - 단어 토큰화 & 불용어 처리

### 형태소 분석 객체 생성하기
okt = Okt()

# %%
### 불용어 정의하기 : 리스트로
stopwords = ["의", "가", "이", "은", "들", "는", "좀",
             "잘", "걍", "과", "도", "를", "으로", "자",
             "에", "와", "한", "하다"]
print(stopwords)
# Out:
# ['의', '가', '이', '은', '들', '는', '좀', '잘', '걍', '과', '도', '를', '으로', '자', '에', '와', '한', '하다']

# %%
### 문장 단위 단어 토큰화 진행하기

tokenized_data = []
for sentence in train_data["document"].to_list() :
    print(sentence)
    
    ### 단어 토큰화 : stem -> 어간(표제어 : 조상단어) 단위로 추출을 의미함
    tokenized_sentence = okt.morphs(sentence, stem=True)
    print(tokenized_sentence)
    
    ### 불용어 처리하기
    stopwords_removed_sentence = [word 
                                    for word in tokenized_sentence
                                         if not word in stopwords]
    # print(stopwords_removed_sentence)
    tokenized_data.append(stopwords_removed_sentence)
    
### 문장 및 단어토큰화 결과는 2차원 리스트
print(tokenized_data)
# Out:
# 어릴때보고 지금다시봐도 재밌어요ㅋㅋ
# ['어리다', '때', '보고', '지금', '다시', '보다', '재밌다', 'ㅋㅋ']
# 디자인을 배우는 학생으로 외국디자이너와 그들이 일군 전통을 통해 발전해가는 문화산업이 부러웠는데 사실 우리나라에서도 그 어려운시절에 끝까지 열정을 지킨 노라노 같은 전통이있어 저와 같은 사람들이 꿈을 꾸고 이뤄나갈 수 있다는 것에 감사합니다
# ['디자인', '을', '배우다', '학생', '으로', '외국', '디자이너', '와', '그', '들', '이', '일군', '전통', '을', '통해', '발전', '하다', '문화', '산업', '이', '부럽다', '사실', '우리나라', '에서도', '그', '어렵다', '시절', '에', '끝', '까지', '열정', '을', '지키다', '노라노', '같다', '전통', '이', '있다', '저', '와', '같다', '사람', '들', '이', '꿈', '을', '꾸다', '이루다', '나가다', '수', '있다', '것', '에', '감사하다']
# 폴리스스토리 시리즈는 부터 뉴까지 버릴께 하나도 없음 최고
# ['폴리스스토리', '시리즈', '는', '부터', '뉴', '까지', '버리다', '하나', '도', '없다', '최고']
# 와 연기가 진짜 개쩔구나 지루할거라고 생각했는데 몰입해서 봤다 그래 이런게 진짜 영화지
# ['오다', '연기', '가', '진짜', '개', '쩔다', '지루하다', '생각', '하다', '몰입', '하다', '보다', '그렇다', '이렇다', '진짜', '영화', '지']
# 안개 자욱한 밤하늘에 떠 있는 초승달 같은 영화
# ['안개', '자욱하다', '밤하늘', '에', '뜨다', '있다', '초승달', '같다', '영화']
# 사랑을 해본사람이라면 처음부터 끝까지 웃을수 있는영화
# ['사랑', '을', '해보다', '사람', '이', '라면', '처음', '부터', '끝', '까지', '웃다', '있다', '영화']
# 완전 감동입니다 다시봐도 감동
# ['완전', '감동', '이다', '다시', '보다', '감동']
# 개들의 전쟁 나오나요 나오면 빠로 보고 싶음
# ['개', '들', '의', '전쟁', '나오다', '나오다', '빠', '로', '보고', '싶다']
# 굿
# ['굿']
# 바보가 아니라 병 쉰 인듯
# ['바보', '가', '아니다', '병', '쉰', '이다']
# 내 나이와 같은 영화를 지금 본 나는 감동적이다하지만 훗날 다시보면대사하나하나 그 감정을완벽하게 이해할것만 같다
# ['내', '나이', '와', '같다', '영화', '를', '지금', '보다', '나', '는', '감동', '적', '이다', '하지만', '훗날', '다시', '보다', '사하나', '하', '나', '그', '감정', '을', '완벽하다', '이해', '하다', '같다']
# 재밌다
# ['재밌다']
# 고질라니무 귀엽다능ㅋㅋ
# ['고질', '라니', '무', '귀엽다', '능', 'ㅋㅋ']
# 영화의 오페라화라고 해야할 작품 극단적 평갈림은 어쩔 수 없는 듯
# ['영화', '의', '오페라', '화', '라고', '하다', '하다', '작품', '극단', '적', '평', '갈림', '은', '어쩔', '수', '없다', '듯']
# 도 반전 좋았제
# ['도', '반전', '좋다', '제']
# 평점 왜 낮아 긴장감 스릴감 진짜 최고인데 진짜 전장에서 느끼는 공포를 생생하게 전해준다
# ['평점', '왜', '낮다', '긴장감', '스릴', '감', '진짜', '최고', '인데', '진짜', '전장', '에서', '느끼다', '공포', '를', '생생하다', '전', '해주다']
# 네고시에이터랑 소재만 같을 뿐 아무런 관련없음
# ['네', '고시', '에', '이', '터', '랑', '소재', '만', '같다', '뿐', '아무렇다', '관련', '없다']
# 단연 최고
# ['단연', '최고']
# 가면 갈수록 더욱 빠져드네요 밀회 화이팅
# ['가면', '갈수록', '더욱', '빠지다', '드', '네', '요', '밀회', '화이팅']
# 어생각없이 봤는데 상당한 수작일본영화 년내 최고로 마음에 들었다강렬한 임팩트가 일품
# ['어', '생각', '없이', '보다', '상당하다', '수', '작', '일', '본', '영화', '년내', '최고', '로', '마음', '에', '들다', '강렬하다', '임팩트', '가', '일품']
# 오랜만에 본 제대로 된 범죄스릴러
# ['오랜', '만', '에', '보다', '제대로', '되다', '범죄', '스릴러']
# 그런 때가 있었다 사랑해도 아니고 그저 좋아한다는 한 마디 말을 꺼내기도 벅차서 밤 잠 설치던 때 커징텅의 교복에 남은 션자이의 볼펜 자국 역시 미처 다 전하지 못한 마음의 형태인 거다
# ['그렇다', '때', '가', '있다', '사랑', '하다', '아니다', '그저', '좋아하다', '하다', '마디', '말', '을', '꺼내다', '벅차다', '밤', '잠', '설치다', '때', '크다', '징텅', '의', '교복', '에', '남다', '션', '자', '이의', '볼펜', '자국', '역시', '미처', '다', '전하', '지', '못', '한', '마음', '의', '형태', '인', '거', '다']
# 마지막씬을 잊을수가 없다
# ['마지막', '씬', '을', '잊다', '없다']
# 강압적용서세뇌적용서에 대한 비판
# ['강압', '적', '용서', '세뇌', '적', '용서', '에', '대한', '비판']
# 중세시대명작 굿 평점이왜이래
# ['중세시대', '명작', '굿', '평점', '이', '왜', '이래']
# 시간짜리 영상이 존재한다면 죽기전에 꼭 한번 보고싶다 아름답고 슬픈  제니퍼코넬리의 눈부신 아역시절 로버트드니로의 마지막 웃는 장면까지 정말 가슴속에 영원히 기억될 최고의 명작이다
# ['시간', '짜다', '영상', '이', '존재', '하다', '죽다', '꼭', '한번', '보다', '아름답다', '슬프다', '제니퍼', '코넬', '리', '의', '눈부시다', '아역시절', '로버트', '드니', '로', '의', '마지막', '웃다', '장면', '까지', '정말', '가슴속', '에', '영원하다', '기억', '되다', '최고', '의', '명작', '이다']
# 사람이 어떻게 저런짓을 할 수가 있는지ㅡㅡ 보는 내가 다 화나더라
# ['사람', '이', '어떻다', '저런', '짓', '을', '하다', '수가', '있다', 'ㅡㅡ', '보다', '내', '가', '다', '화나다']
# 인간의 잠재된 악마성은 여러 시간과 공간 속에서 존속해왔다 이 다큐는 그것을 엉뚱하면서도 광적으로 재현하였다
# ['인간', '의', '잠재', '되다', '악마', '성은', '여러', '시간', '과', '공간', '속', '에서', '존속', '해오다', '이', '다큐', '는', '그것', '을', '엉뚱하다', '광', '적', '으로', '재현', '하다']
# 최고다 삼일동안 쉬는틈틈이 잠도 줄여가면서 봤다여운이 남는다
# ['최고다', '삼일', '동안', '쉬다', '틈틈이', '잠도', '줄이다', '보다', '여운', '이', '남다']
# 실화여서 더욱 충격 다시는 어디에서도 일어나서는 안될 경각심을 일깨워주는 영화
# ['실화', '여서', '더욱', '충격', '다시다', '어디', '에서도', '일어나서', '는', '안되다', '경', '각심', '을', '일', '깨우다', '영화']
# 존 그라샴 작품이라면 한번쯤은 볼가치가 있지
# ['존', '그라샴', '작품', '이', '라면', '한번', '쯤', '은', '보다', '있다']
# 농아인문화에 대한 알아야 합니다
# ['농아인', '문화', '에', '대한', '알다', '하다']
# 이거어렸을때되게재밌게봄ㅋㅋ이정재 이범수ㅋㅋㅋㅋ연기쩜
# ['이', '거', '어리다', '때', '되게', '재밌다', '봄', 'ㅋㅋ', '이정재', '이범수', 'ㅋㅋㅋㅋ', '연기', '쩜']
# 친구의 우정이 매우 감동적이었다
# ['친구', '의', '우정', '이', '매우', '감동', '적', '이다']
# 굿굿굿 또해라또해라 제발 ㅠㅠ
# ['굿굿굿', '또', '하다', '또해', '라', '제발', 'ㅠㅠ']
# 아 재미있다 이 말이 너무 어울린다
# ['아', '재미있다', '이', '말', '이', '너무', '어울리다']
# 제이크 질렌할넌 대체 못하는 연기가 뭐냐
# ['제이크', '질렌할넌', '대체', '못', '하다', '연기', '가', '뭐', '냐']
# 보는내내 입가에 미소가 샤방샤방했던 영화
# ['보다', '입가', '에', '미소', '가', '샤방샤방했던', '영화']
# 원표가 왜 조연이양 젤 많이 나오는구만ㅋㅋ 재미있음
# ['원표', '가', '왜', '조연', '이양', '젤', '많이', '나오다', 'ㅋㅋ', '재미있다']
# 마치 바다속  아쿠아리움속으로 들어간듯한 느낌의 영화 어린자녀들에게 강추
# ['마치', '바다', '속', '아쿠아리움', '속', '으로', '들어가다', '한', '느낌', '의', '영화', '어리다', '자녀', '들', '에게', '강추']
# 정의를 세우는 콜트 콜텍 노동자들 이야기
# ['정의', '를', '세우다', '콜트', '콜텍', '노동자', '들', '이야기']
# 이 영화보면 브라질 가고싶은 마음이 사라질것이다
# ['이', '영', '화보', '면', '브라질', '가다', '마음', '이', '사라지다']
# 난 남자지만 영화내내 마음이 울렸다 그리고 내가 좋아하는 두 여배우
# ['난', '남자', '지만', '영화', '내내', '마음', '이', '울리다', '그리고', '내', '가', '좋아하다', '두', '여배우']
# 도법 멤버들 모두 기대됨
# ['도법', '멤버', '들', '모두', '기대', '되다']
# 정말 재미있게 본 영화였다 액션 최고
# ['정말', '재미있다', '보다', '영화', '이다', '액션', '최고']
# 내가 남자라그런가 이거 겁나 긴장감있고 흥미진진하던데ㄷㄷ 나만그런가워낙에 격투씬을 좋아해서ㅋㅋㅋ 그냥 아무생각없이 집에서 스마트티비로 봐서 재밌었나봄 이거 뭔영화인지도 모르고 암살에 나온 이정재 있길래 걍봄 ㅋㅋ 하여튼 너무 재밌게 봤음
# ['내', '가', '남자', '라', '그', '런가', '이', '거', '겁나다', '긴장감', '있다', '흥미진진', '하다', 'ㄷㄷ', '나', '만', '그', '런가', '워낙', '에', '격투씬', '을', '좋아하다', 'ㅋㅋㅋ', '그냥', '아무', '생각', '없이', '집', '에서', '스마트', '티비', '로', '보다', '재밌다', '봄', '이', '거', '뭔', '영화', '인지도', '모르다', '암살', '에', '나오다', '이정재', '있다', '걍', '봄', 'ㅋㅋ', '하여튼', '너무', '재밌다', '보다']
# 인정할건 인정하자 ㅆ파르 년들아 북한이 살만하고 좋으면 왜목숨걸고 대한민국 오는건데 어 그거부터 납득시키고 나불거려라 종북 박평식같은 좋가튼년들아
# ['인정', '하다', '인정', '하다', 'ㅆ', '파르', '년', '들', '아', '북한', '이', '살', '만', '하고', '좋다', '왜', '목숨', '걸다', '대한민국', '오다', '어', '그거', '부터', '납득', '시키다', '나불', '거려', '라', '종북', '박평', '식', '같다', '좋다', '틀다', '년', '들', '아']
# 잊을 수 없는 그대여 월이 되고 비가 내려야 그대가 보이기 시작합니다
# ['잊다', '수', '없다', '그대', '여', '월', '이', '되다', '비', '가', '내다', '그대', '가', '보이다', '시작', '하다']
# 반가운 얼굴들ㅋㅋㅋ 여주인공 넘 매력적이구 유쾌한영화였어요
# ['반갑다', '얼굴', '들', 'ㅋㅋㅋ', '여', '주인공', '넘다', '매력', '적', '이구', '유쾌하다', '영화', '이다']
# 내용이너무좋아요ㅎ
# ['내', '용이', '너무', '좋다', 'ㅎ']
# 정말 요즘 아이돌들이 다 배우 해먹네 할정도로 연기를 잘한다
# ['정말', '요즘', '아이돌', '들', '이', '다', '배우', '해먹', '네', '하다', '정도', '로', '연기', '를', '잘', '하다']
# 정말재밋게 봣는대요 어디서 받을수잇조
# ['정말재밋', '게', '봣는대', '요', '어디서', '받다', '잇다', '조']
# 탱고 음악의 감동이 밀려온다
# ['탱고', '음악', '의', '감동', '이', '밀려오다']
# 평생 못봤으면 후회할뻔한 따뜻한 명작
# ['평생', '못', '보다', '후회', '하다', '뻔하다', '따뜻하다', '명작']
# 이런 드라마가 많이 나왔으면 좋겠어요 생각할 것도 많고 영상미도 아름답고 캐릭터도 다 매력 있었어요 여러가지로 다 매력 있었던 드라마였어요
# ['이렇다', '드라마', '가', '많이', '나오다', '좋다', '생각', '하다', '것', '도', '많다', '영상', '미도', '아름답다', '캐릭터', '도', '다', '매력', '있다', '여러가지', '로', '다', '매력', '있다', '드라마', '이다']
# 정말 최고였는데 마지막이 이련결말 싫다ㅠ
# ['정말', '최고', '이다', '마지막', '이', '이다', '결말', '싫다', 'ㅠ']
# 너무 슬프네요 왜 이제 알게된 영화였는지
# ['너무', '슬프다', '왜', '이제', '알', '게', '되다', '영화', '이다']
# 잔잔하고 재미도 있어서 좋았다
# ['잔잔하다', '재미', '도', '있다', '좋다']
# 내가 본 영화 중 영순위
# ['내', '가', '보다', '영화', '중', '영', '순위']
# 재밌습니다재밌습니다
# ['재밌다', '재밌다']
# 상당히 훌륭한 영화
# ['상당하다', '훌륭하다', '영화']
# 역시신동엽ㅋ순간 캐치 탁얄밉게 웃긴 미워할수없고감탄이영자랑 함 대박일텐데 왠이동욱
# ['역시', '신동엽', 'ㅋ', '순간', '캐치', '탁', '얄밉다', '웃기다', '미워하다', '없다', '감탄', '이영자', '랑', '함', '대박', '일텐데', '왠', '이동욱']
# 내 인생의 영화
# ['내', '인생', '의', '영화']
# 전작에 비해 떨어지는건 사실이지만 쓰레기 한국영화도 점대 별로없는데 헐니들 너무하다
# ['전작', '에', '비다', '떨어지다', '사실', '이지만', '쓰레기', '한국영', '화', '도', '점', '대', '별로', '없다', '헐다', '들다', '너무하다']
# 지금은 다소 진부할수있어도 그당시엔 눈물 한사발 흘리게해준 영화
# ['지금', '은', '다소', '진부하다', '그', '당시', '엔', '눈물', '한', '사발', '흘리다', '해주다', '영화']
# 신부로서의 사명감을 처절히 실천하는 제리 자신마저 부정하는 로키의 우정
# ['신부', '로서', '의', '사', '명감', '을', '처절하다', '실천', '하다', '제리', '자신', '마저', '부정', '하다', '로키', '의', '우정']
#  원주율메이커
# ['원주율', '메이커']
# 추석때 특선영화 해주는거 봤는데 진짜 가족들끼리 보기 좋은 영화였음
# ['추석', '때', '특선영화', '해주다', '보다', '진짜', '가족', '들', '끼리', '보기', '좋다', '영화', '이다']
# 우리애기첫영화 너무너무 잘선택한거같아요ㅎ굳
# ['우리', '애기', '첫', '영화', '너무', '너무', '자다', '선택', '한', '거', '같다', 'ㅎ', '굳다']
# 재미있어요
# ['재미있다']
# 생각보다괜찬은조합인거같다
# ['생각', '보다', '괜찬', '은', '조합', '인거', '같다']
# 저게바로 이시대의 어머니
# ['저', '게', '바로', '이', '시', '대의', '어머니']
# 나만 재밌으면 되지 뭐나도 원작 본 사람이지만 드래곤볼 에볼루션보다는 잘 만듬 ㅇㅇ
# ['나', '만', '재밌다', '되다', '뭐', '나다', '원작', '보다', '사람', '이지만', '드래곤볼', '에볼루션', '보다는', '자다', '만듬', 'ㅇㅇ']
# 우리나라 예능 중 최고
# ['우리나라', '예능', '중', '최고']
# 방학때 아침에 졸린눈 비비면서 우연히 티비채널 돌리다 이 영화를 보게된건 정말
# ['방학', '때', '아침', '에', '졸리다', '눈', '비비다', '우연히', '티비', '채널', '돌리다', '이', '영화', '를', '보다', '되다', '정말']
# 마음이 너무 아프다 이 영화는 다시 볼 수 없을 것 같다
# ['마음', '이', '너무', '아프다', '이', '영화', '는', '다시', '볼', '수', '없다', '것', '같다']
# 엔트랩먼트
# ['엔트랩먼트']
# 정말 재미있게 보았음 권력에는 친구도 의리도 없다는 역사적 사실을 훌륭하게 깨우쳐줌
# ['정말', '재미있다', '보다', '권력', '에는', '친구', '도', '의리', '도', '없다', '역사', '적', '사실', '을', '훌륭하다', '깨우치다', '줌']
# 처음에는 초롱 팬심으로 봤는데 갈수록 내용과 어울리는 배경음악들이 너무 달달하고 보고 있으면 행복해지네요 완전 재밌습니다
# ['처음', '에는', '초롱', '팬심', '으로', '보다', '갈수록', '내용', '과', '어울리다', '배경음악', '들', '이', '너무', '달달', '하고', '보고', '있다', '행복하다', '완전', '재밌다']
# 너무너무재밌게보고있어요 중간부터 본방사수했지만 스토리가 탄탄하고 흥미진진해서 화부터 다찾아서 봤네요 배우들 연기도 어디하나빠지는데가없네요 요새는 수백향만챙겨봐요
# ['너무', '너무', '재밌다', '보다', '중간', '부터', '본방', '사수', '하다', '스토리', '가', '탄탄하다', '흥미진진', '하다', '화', '부터', '다', '찾다', '보다', '배우', '들', '연기', '도', '어디', '하', '나빠지다', '없다', '요새', '는', '수백향', '만', '챙기다', '보다']
# 내가 없어질 내인생 제목을 참 잘 지었다
# ['내', '가', '없어지다', '내', '인생', '제목', '을', '차다', '자다', '지다']
# 음 화질은좋은데재미가없네
# ['음', '화질', '은', '좋다', '재미', '가', '없다']
# 가을로 는 가을에 감동이네요
# ['가을로', '늘다', '가을', '에', '감동', '이네', '요']
#  때문에 봤는데 이건뭐 와라는 말밖에 안나오네 벌써 년전인데 이런퀄리티가 나오다니 대단하다
# ['때문', '에', '보다', '이건', '뭐', '오다', '말', '밖에', '안', '나오다', '벌써', '년전', '인데', '이런', '퀄리티', '가', '나오다', '대단하다']
# 중인데 일단 까지봣다 뭐 말할것도없다장국영 자살이 안타깝다
# ['중', '인데', '일단', '까지봣다', '뭐', '말', '하다', '없다', '장국영', '자살', '이', '안타깝다']
# 사실적이어서 더 극적인
# ['사실', '적', '이어서', '더', '극적', '인']
# 뀰잼이다뀰잼이라구여
# ['뀰잼', '이다', '뀰잼', '이라', '구', '여']
# 짱 재미있어요오 ㅇ
# ['짱', '재미있다', '오', 'ㅇ']
# 첫느낌은예전에양심냉장고와 비슷한거같더라고요 보면서 감정이움찔 해져요 그런대 한가지부탁 드리고싶은게연기자좀보호해주세요 욕이나폭력은 걱정되요 저어릴적에성추행을상가에서모든사람이목격했는데저만증언했었거든요덕분에청소년인저는계속경찰서를왔다갔다해야했죠
# ['첫', '느낌', '은', '예전', '에', '양심', '냉장고', '와', '비슷하다', '같다', '보다', '감정', '이', '움찔', '하다', '그렇다', '한가지', '부탁', '드리다', '싶다', '연기자', '좀', '보호', '해주다', '욕', '이나', '폭력', '은', '걱정', '되다', '저', '어리다', '적', '에', '성추행', '을', '상가', '에서', '모든', '사람', '이', '목격', '하다', '저만', '증언', '하다', '덕분', '에', '청소년', '인', '저', '는', '계속', '경찰서', '를', '오다', '가다', '야하다']
# 남자주인공 넘 섹시하고 멋있쪙ㅋㅋㅋㅋ
# ['남자', '주인공', '넘다', '섹시하다', '멋있쪙', 'ㅋㅋㅋㅋ']
# 어설픈건 사실이었다 하지 재밋었다 ㅎ
# ['어설프다', '사다', '하다', '재밋었다', 'ㅎ']
# 영화 중 세기 최고라고 할 수 있다이걸 평점 낮게주는 사람은 정말 볼줄을 모르는것
# ['영화', '중', '세기', '최고', '라고', '하다', '수', '있다', '이', '걸', '평점', '낮다', '사람', '은', '정말', '보다', '모르다']
# 년에 비디오방에서 친구랑 봤는데 정말 좋았다는 느낌이 지금까지또 보고싶네요
# ['년', '에', '비디오', '방', '에서', '친구', '랑', '보다', '정말', '좋다', '느낌', '이', '지금', '까지', '또', '보다']
# 빨리 보고싶다헌데 오래 기다려야 될거가틈
# ['빨리', '보다', '허다', '오래', '기다리다', '되다', '틈']
# 남기남 감독 그 이름 하나 만으로도 점
# ['남기남', '감독', '그', '이름', '하나', '만으로도', '점']
# 진짜 최고다 최고 성룡형님 마이 우상
# ['진짜', '최고다', '최고', '성룡', '형님', '마이', '우상']
#  당신이 좋아하는 장르는 뭐요 이영화에도 저영화에도 이런장르는 싫다니원
# ['당신', '이', '좋아하다', '장르', '는', '뭐', '요', '이영화', '에도', '저', '영화', '에도', '이런', '장르', '는', '싫다', '원']
# 지금까지 본영화중에 최고다
# ['지금', '까지', '본', '영화', '중', '에', '최고다']
# 매회리타가자꾸거슬려서죽었으면좋겠다고생각했는데ㅠㅠ죄책감에나도잠못이룬다
# ['매회', '리타', '가', '자꾸', '거슬리다', '죽다', '좋다', '생각', '하다', 'ㅠㅠ', '죄책감', '에나', '도잠', '못', '이루다']
# 어릴 때보고 커서 다시 봤는데 진짜 잘 만든 영화였네 웃음과 감동을 잘 이어 붙였고 정치에 대한 비판이랑 묘사도 굉장히 잘 표현했다 흥행했었는지 기억은 안나지만 절대 낮은 평점의 영화가 아니라고 생각한다 연기자들 연기하는 디테일만 봐도 따봉임
# ['어리다', '때', '보고', '커서', '다시', '보다', '진짜', '자다', '만들다', '영화', '이다', '웃음', '과', '감동', '을', '자다', '이다', '붙이다', '정치', '에', '대한', '비판', '이랑', '묘사', '도', '굉장하다', '자다', '표현', '하다', '흥행', '하다', '기억', '은', '안나', '지만', '절대', '낮다', '평점', '의', '영화', '가', '아니다', '생각', '하다', '연기자', '들', '연기', '하다', '디테', '일만', '보다', '따다', '봉임']
# [['어리다', '때', '보고', '지금', '다시', '보다', '재밌다', 'ㅋㅋ'], ['디자인', '을', '배우다', '학생', '외국', '디자이너', '그', '일군', '전통', '을', '통해', '발전', '문화', '산업', '부럽다', '사실', '우리나라', '에서도', '그', '어렵다', '시절', '끝', '까지', '열정', '을', '지키다', '노라노', '같다', '전통', '있다', '저', '같다', '사람', '꿈', '을', '꾸다', '이루다', '나가다', '수', '있다', '것', '감사하다'], ['폴리스스토리', '시리즈', '부터', '뉴', '까지', '버리다', '하나', '없다', '최고'], ['오다', '연기', '진짜', '개', '쩔다', '지루하다', '생각', '몰입', '보다', '그렇다', '이렇다', '진짜', '영화', '지'], ['안개', '자욱하다', '밤하늘', '뜨다', '있다', '초승달', '같다', '영화'], ['사랑', '을', '해보다', '사람', '라면', '처음', '부터', '끝', '까지', '웃다', '있다', '영화'], ['완전', '감동', '이다', '다시', '보다', '감동'], ['개', '전쟁', '나오다', '나오다', '빠', '로', '보고', '싶다'], ['굿'], ['바보', '아니다', '병', '쉰', '이다'], ['내', '나이', '같다', '영화', '지금', '보다', '나', '감동', '적', '이다', '하지만', '훗날', '다시', '보다', '사하나', '하', '나', '그', '감정', '을', '완벽하다', '이해', '같다'], ['재밌다'], ['고질', '라니', '무', '귀엽다', '능', 'ㅋㅋ'], ['영화', '오페라', '화', '라고', '작품', '극단', '적', '평', '갈림', '어쩔', '수', '없다', '듯'], ['반전', '좋다', '제'], ['평점', '왜', '낮다', '긴장감', '스릴', '감', '진짜', '최고', '인데', '진짜', '전장', '에서', '느끼다', '공포', '생생하다', '전', '해주다'], ['네', '고시', '터', '랑', '소재', '만', '같다', '뿐', '아무렇다', '관련', '없다'], ['단연', '최고'], ['가면', '갈수록', '더욱', '빠지다', '드', '네', '요', '밀회', '화이팅'], ['어', '생각', '없이', '보다', '상당하다', '수', '작', '일', '본', '영화', '년내', '최고', '로', '마음', '들다', '강렬하다', '임팩트', '일품'], ['오랜', '만', '보다', '제대로', '되다', '범죄', '스릴러'], ['그렇다', '때', '있다', '사랑', '아니다', '그저', '좋아하다', '마디', '말', '을', '꺼내다', '벅차다', '밤', '잠', '설치다', '때', '크다', '징텅', '교복', '남다', '션', '이의', '볼펜', '자국', '역시', '미처', '다', '전하', '지', '못', '마음', '형태', '인', '거', '다'], ['마지막', '씬', '을', '잊다', '없다'], ['강압', '적', '용서', '세뇌', '적', '용서', '대한', '비판'], ['중세시대', '명작', '굿', '평점', '왜', '이래'], ['시간', '짜다', '영상', '존재', '죽다', '꼭', '한번', '보다', '아름답다', '슬프다', '제니퍼', '코넬', '리', '눈부시다', '아역시절', '로버트', '드니', '로', '마지막', '웃다', '장면', '까지', '정말', '가슴속', '영원하다', '기억', '되다', '최고', '명작', '이다'], ['사람', '어떻다', '저런', '짓', '을', '수가', '있다', 'ㅡㅡ', '보다', '내', '다', '화나다'], ['인간', '잠재', '되다', '악마', '성은', '여러', '시간', '공간', '속', '에서', '존속', '해오다', '다큐', '그것', '을', '엉뚱하다', '광', '적', '재현'], ['최고다', '삼일', '동안', '쉬다', '틈틈이', '잠도', '줄이다', '보다', '여운', '남다'], ['실화', '여서', '더욱', '충격', '다시다', '어디', '에서도', '일어나서', '안되다', '경', '각심', '을', '일', '깨우다', '영화'], ['존', '그라샴', '작품', '라면', '한번', '쯤', '보다', '있다'], ['농아인', '문화', '대한', '알다'], ['거', '어리다', '때', '되게', '재밌다', '봄', 'ㅋㅋ', '이정재', '이범수', 'ㅋㅋㅋㅋ', '연기', '쩜'], ['친구', '우정', '매우', '감동', '적', '이다'], ['굿굿굿', '또', '또해', '라', '제발', 'ㅠㅠ'], ['아', '재미있다', '말', '너무', '어울리다'], ['제이크', '질렌할넌', '대체', '못', '연기', '뭐', '냐'], ['보다', '입가', '미소', '샤방샤방했던', '영화'], ['원표', '왜', '조연', '이양', '젤', '많이', '나오다', 'ㅋㅋ', '재미있다'], ['마치', '바다', '속', '아쿠아리움', '속', '들어가다', '느낌', '영화', '어리다', '자녀', '에게', '강추'], ['정의', '세우다', '콜트', '콜텍', '노동자', '이야기'], ['영', '화보', '면', '브라질', '가다', '마음', '사라지다'], ['난', '남자', '지만', '영화', '내내', '마음', '울리다', '그리고', '내', '좋아하다', '두', '여배우'], ['도법', '멤버', '모두', '기대', '되다'], ['정말', '재미있다', '보다', '영화', '이다', '액션', '최고'], ['내', '남자', '라', '그', '런가', '거', '겁나다', '긴장감', '있다', '흥미진진', 'ㄷㄷ', '나', '만', '그', '런가', '워낙', '격투씬', '을', '좋아하다', 'ㅋㅋㅋ', '그냥', '아무', '생각', '없이', '집', '에서', '스마트', '티비', '로', '보다', '재밌다', '봄', '거', '뭔', '영화', '인지도', '모르다', '암살', '나오다', '이정재', '있다', '봄', 'ㅋㅋ', '하여튼', '너무', '재밌다', '보다'], ['인정', '인정', 'ㅆ', '파르', '년', '아', '북한', '살', '만', '하고', '좋다', '왜', '목숨', '걸다', '대한민국', '오다', '어', '그거', '부터', '납득', '시키다', '나불', '거려', '라', '종북', '박평', '식', '같다', '좋다', '틀다', '년', '아'], ['잊다', '수', '없다', '그대', '여', '월', '되다', '비', '내다', '그대', '보이다', '시작'], ['반갑다', '얼굴', 'ㅋㅋㅋ', '여', '주인공', '넘다', '매력', '적', '이구', '유쾌하다', '영화', '이다'], ['내', '용이', '너무', '좋다', 'ㅎ'], ['정말', '요즘', '아이돌', '다', '배우', '해먹', '네', '정도', '로', '연기'], ['정말재밋', '게', '봣는대', '요', '어디서', '받다', '잇다', '조'], ['탱고', '음악', '감동', '밀려오다'], ['평생', '못', '보다', '후회', '뻔하다', '따뜻하다', '명작'], ['이렇다', '드라마', '많이', '나오다', '좋다', '생각', '것', '많다', '영상', '미도', '아름답다', '캐릭터', '다', '매력', '있다', '여러가지', '로', '다', '매력', '있다', '드라마', '이다'], ['정말', '최고', '이다', '마지막', '이다', '결말', '싫다', 'ㅠ'], ['너무', '슬프다', ' ...

# %%
### Word2Vec 훈련모델 생성 및 훈련시키기
from gensim.models import Word2Vec

# %%
model = Word2Vec(sentences = tokenized_data,
                 vector_size = 100,
                 window = 5,
                 min_count = 5,
                 workers = 4,
                 sg = 0)

# %%
### 훈련이 끝나면 단어임베딩이 완료됨
# - 단어 임베딩 행렬의 크기 확인하기
## 42개 단어, 100개
model.wv.vectors.shape
# Out:
# (42, 100)

# %%
### 유사단어 조회하기
model.wv.most_similar("감동")
# Out:
# [('저', 0.15991708636283875),
#  ('영화', 0.15967068076133728),
#  ('을', 0.1563413143157959),
#  ('에서', 0.14823421835899353),
#  ('내', 0.14398179948329926),
#  ('재밌다', 0.13573001325130463),
#  ('나오다', 0.12083221226930618),
#  ('재미있다', 0.09644678235054016),
#  ('적', 0.08289238065481186),
#  ('같다', 0.07847648859024048)]

# %%
### 유사 단어만(정확도 제외) 리스트로 조회하기
## 첫번째~.. 튜플의 값의 0번째 값
## 한줄코딩에서의 최종결과값은 (오른쪽으로 코딩하다가)제일 왼쪽
[x[0] for x in model.wv.most_similar("감동")]
# Out:
# ['저', '영화', '을', '에서', '내', '재밌다', '나오다', '재미있다', '적', '같다']
